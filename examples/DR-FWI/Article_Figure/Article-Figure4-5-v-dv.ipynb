# %%
import numpy as np
import matplotlib.pyplot as plt
import os

from ADFWI.utils.assessment_metric import MAPE, MSE, SNR, SSIM

base_path = "/home/bingxing2/ailab/scxlab0055/project/04_Inversion/ADFWI-github/examples/DR-FWI/reparameterization-strategy/Marmousi2-nowater/data"

init_model = np.load(os.path.join(base_path,"model/init_model.npz"))
true_model = np.load(os.path.join(base_path,"model/true_model.npz"))
init_v   = init_model["vp"]
init_rho = init_model["rho"]
true_v   = true_model["vp"]
true_rho = true_model["rho"]

ox, oz  = 0, 0        
nz, nx  = 76, 200      
dx, dz  = 40, 40         
nt, dt  = 1600, 0.003     
nabc    = 30                 
x       = np.arange(nx)*dx/1000
z       = np.arange(nz)*dz/1000
x_mesh,z_mesh = np.meshgrid(x,z)
src_z = np.array([1  for i in range(2,nx-1,5)])*dz/1000
src_x = np.array([i  for i in range(2,nx-1,5)])*dx/1000
rcv_z = np.array([1  for i in range(0,nx,1)])*dz/1000
rcv_x = np.array([j  for j in range(0,nx,1)])*dz/1000
vmin = true_v.min();vmax = true_v.max()  

MAX_ITER = 300

# %% [markdown]
# ## V

# %%
itervp_baseline      = np.load(os.path.join(base_path,"GC/inversion-vp-baseline/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x64       = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x128      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x256      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x512      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x64       = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x128      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x256      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x512      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x64       = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x128      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x256      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x512      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN4x64       = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-4x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN4x128      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-4x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN4x256      = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-4x256/iter_vp.npz"))["data"][:MAX_ITER]


iterloss_baseline    = np.load(os.path.join(base_path,"GC/inversion-vp-baseline/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x64     = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x128    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x256    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x512    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-1x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x64     = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x128    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x256    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x512    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-2x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x64     = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x128    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x256    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x512    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-3x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN4x64     = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-4x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN4x128    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-4x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN4x256    = np.load(os.path.join(base_path,"GC/inversion-vp-CNN-4x256/iter_loss.npz"))["data"][:MAX_ITER]

# %%
itervp_MLP2x100      = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x100/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP2x1000     = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x1000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP2x2000     = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x2000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP2x3000     = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x3000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x100      = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x100/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x1000     = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x1000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x2000     = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x2000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x3000     = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x3000/iter_vp.npz"))["data"][:MAX_ITER]


iterloss_MLP2x100    = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x100/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP2x1000   = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x1000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP2x2000   = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x2000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP2x3000   = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-2x3000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x100    = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x100/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x1000   = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x1000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x2000   = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x2000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x3000   = np.load(os.path.join(base_path,"GC/inversion-vp-MLP-3x3000/iter_loss.npz"))["data"][:MAX_ITER]

# %%
itervp_Unet1x64       = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet1x128      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet1x256      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet1x512      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x64       = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x128      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x256      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x512      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x64       = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x128      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x256      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x512      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet4x64       = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-4x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet4x128      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-4x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet4x256      = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-4x256/iter_vp.npz"))["data"][:MAX_ITER]

iterloss_Unet1x64    = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet1x128   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet1x256   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet1x512   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-1x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x64    = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x128   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x256   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x512   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-2x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x64    = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x128   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x256   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x512   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-3x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet4x64    = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-4x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet4x128   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-4x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet4x256   = np.load(os.path.join(base_path,"GC/inversion-vp-Unet-4x256/iter_loss.npz"))["data"][:MAX_ITER]

# %%
# MAPE Loss
vp_init_model_MAPE      =           MAPE(true_v,init_v)

vp_baseline_MAPE        = np.insert(MAPE(true_v,itervp_baseline),0,vp_init_model_MAPE)

vp_CNN_MAPE_1x64        = np.insert(MAPE(true_v,itervp_CNN1x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_1x128       = np.insert(MAPE(true_v,itervp_CNN1x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_1x256       = np.insert(MAPE(true_v,itervp_CNN1x256),0,vp_init_model_MAPE)
vp_CNN_MAPE_1x512       = np.insert(MAPE(true_v,itervp_CNN1x512),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x64        = np.insert(MAPE(true_v,itervp_CNN2x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x128       = np.insert(MAPE(true_v,itervp_CNN2x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x256       = np.insert(MAPE(true_v,itervp_CNN2x256),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x512       = np.insert(MAPE(true_v,itervp_CNN2x512),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x64        = np.insert(MAPE(true_v,itervp_CNN3x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x128       = np.insert(MAPE(true_v,itervp_CNN3x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x256       = np.insert(MAPE(true_v,itervp_CNN3x256),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x512       = np.insert(MAPE(true_v,itervp_CNN3x512),0,vp_init_model_MAPE)
vp_CNN_MAPE_4x64        = np.insert(MAPE(true_v,itervp_CNN4x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_4x128       = np.insert(MAPE(true_v,itervp_CNN4x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_4x256       = np.insert(MAPE(true_v,itervp_CNN4x256),0,vp_init_model_MAPE)

vp_MLP_MAPE_2x100       = np.insert(MAPE(true_v,itervp_MLP2x100),0,vp_init_model_MAPE)
vp_MLP_MAPE_2x1000      = np.insert(MAPE(true_v,itervp_MLP2x1000),0,vp_init_model_MAPE)
vp_MLP_MAPE_2x2000      = np.insert(MAPE(true_v,itervp_MLP2x2000),0,vp_init_model_MAPE)
vp_MLP_MAPE_2x3000      = np.insert(MAPE(true_v,itervp_MLP2x3000),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x100       = np.insert(MAPE(true_v,itervp_MLP3x100),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x1000      = np.insert(MAPE(true_v,itervp_MLP3x1000),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x2000      = np.insert(MAPE(true_v,itervp_MLP3x2000),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x3000      = np.insert(MAPE(true_v,itervp_MLP3x3000),0,vp_init_model_MAPE)


vp_Unet_MAPE_1x64        = np.insert(MAPE(true_v,itervp_Unet1x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_1x128       = np.insert(MAPE(true_v,itervp_Unet1x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_1x256       = np.insert(MAPE(true_v,itervp_Unet1x256),0,vp_init_model_MAPE)
vp_Unet_MAPE_1x512       = np.insert(MAPE(true_v,itervp_Unet1x512),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x64        = np.insert(MAPE(true_v,itervp_Unet2x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x128       = np.insert(MAPE(true_v,itervp_Unet2x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x256       = np.insert(MAPE(true_v,itervp_Unet2x256),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x512       = np.insert(MAPE(true_v,itervp_Unet2x512),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x64        = np.insert(MAPE(true_v,itervp_Unet3x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x128       = np.insert(MAPE(true_v,itervp_Unet3x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x256       = np.insert(MAPE(true_v,itervp_Unet3x256),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x512       = np.insert(MAPE(true_v,itervp_Unet3x512),0,vp_init_model_MAPE)
vp_Unet_MAPE_4x64        = np.insert(MAPE(true_v,itervp_Unet4x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_4x128       = np.insert(MAPE(true_v,itervp_Unet4x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_4x256       = np.insert(MAPE(true_v,itervp_Unet4x256),0,vp_init_model_MAPE)

# %%
# SNR
vp_init_model_SNR      =           SNR(true_v,init_v)

vp_baseline_SNR        = np.insert(SNR(true_v,itervp_baseline),0,vp_init_model_SNR)

vp_CNN_SNR_1x64        = np.insert(SNR(true_v,itervp_CNN1x64),0 ,vp_init_model_SNR)
vp_CNN_SNR_1x128       = np.insert(SNR(true_v,itervp_CNN1x128),0,vp_init_model_SNR)
vp_CNN_SNR_1x256       = np.insert(SNR(true_v,itervp_CNN1x256),0,vp_init_model_SNR)
vp_CNN_SNR_1x512       = np.insert(SNR(true_v,itervp_CNN1x512),0,vp_init_model_SNR)
vp_CNN_SNR_2x64        = np.insert(SNR(true_v,itervp_CNN2x64),0 ,vp_init_model_SNR)
vp_CNN_SNR_2x128       = np.insert(SNR(true_v,itervp_CNN2x128),0,vp_init_model_SNR)
vp_CNN_SNR_2x256       = np.insert(SNR(true_v,itervp_CNN2x256),0,vp_init_model_SNR)
vp_CNN_SNR_2x512       = np.insert(SNR(true_v,itervp_CNN2x512),0,vp_init_model_SNR)
vp_CNN_SNR_3x64        = np.insert(SNR(true_v,itervp_CNN3x64),0 ,vp_init_model_SNR)
vp_CNN_SNR_3x128       = np.insert(SNR(true_v,itervp_CNN3x128),0,vp_init_model_SNR)
vp_CNN_SNR_3x256       = np.insert(SNR(true_v,itervp_CNN3x256),0,vp_init_model_SNR)
vp_CNN_SNR_3x512       = np.insert(SNR(true_v,itervp_CNN3x512),0,vp_init_model_SNR)
vp_CNN_SNR_4x64        = np.insert(SNR(true_v,itervp_CNN4x64),0,vp_init_model_SNR)
vp_CNN_SNR_4x128       = np.insert(SNR(true_v,itervp_CNN4x128),0,vp_init_model_SNR)
vp_CNN_SNR_4x256       = np.insert(SNR(true_v,itervp_CNN4x256),0,vp_init_model_SNR)


vp_MLP_SNR_2x100       = np.insert(SNR(true_v,itervp_MLP2x100) ,0,vp_init_model_SNR)
vp_MLP_SNR_2x1000      = np.insert(SNR(true_v,itervp_MLP2x1000),0,vp_init_model_SNR)
vp_MLP_SNR_2x2000      = np.insert(SNR(true_v,itervp_MLP2x2000),0,vp_init_model_SNR)
vp_MLP_SNR_2x3000      = np.insert(SNR(true_v,itervp_MLP2x3000),0,vp_init_model_SNR)
vp_MLP_SNR_3x100       = np.insert(SNR(true_v,itervp_MLP3x100) ,0,vp_init_model_SNR)
vp_MLP_SNR_3x1000      = np.insert(SNR(true_v,itervp_MLP3x1000),0,vp_init_model_SNR)
vp_MLP_SNR_3x2000      = np.insert(SNR(true_v,itervp_MLP3x2000),0,vp_init_model_SNR)
vp_MLP_SNR_3x3000      = np.insert(SNR(true_v,itervp_MLP3x3000),0,vp_init_model_SNR)


vp_Unet_SNR_1x64        = np.insert(SNR(true_v,itervp_Unet1x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_1x128       = np.insert(SNR(true_v,itervp_Unet1x128),0,vp_init_model_SNR)
vp_Unet_SNR_1x256       = np.insert(SNR(true_v,itervp_Unet1x256),0,vp_init_model_SNR)
vp_Unet_SNR_1x512       = np.insert(SNR(true_v,itervp_Unet1x512),0,vp_init_model_SNR)
vp_Unet_SNR_2x64        = np.insert(SNR(true_v,itervp_Unet2x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_2x128       = np.insert(SNR(true_v,itervp_Unet2x128),0,vp_init_model_SNR)
vp_Unet_SNR_2x256       = np.insert(SNR(true_v,itervp_Unet2x256),0,vp_init_model_SNR)
vp_Unet_SNR_2x512       = np.insert(SNR(true_v,itervp_Unet2x512),0,vp_init_model_SNR)
vp_Unet_SNR_3x64        = np.insert(SNR(true_v,itervp_Unet3x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_3x128       = np.insert(SNR(true_v,itervp_Unet3x128),0,vp_init_model_SNR)
vp_Unet_SNR_3x256       = np.insert(SNR(true_v,itervp_Unet3x256),0,vp_init_model_SNR)
vp_Unet_SNR_3x512       = np.insert(SNR(true_v,itervp_Unet3x512),0,vp_init_model_SNR)
vp_Unet_SNR_4x64        = np.insert(SNR(true_v,itervp_Unet4x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_4x128       = np.insert(SNR(true_v,itervp_Unet4x128),0,vp_init_model_SNR)
vp_Unet_SNR_4x256       = np.insert(SNR(true_v,itervp_Unet4x256),0,vp_init_model_SNR)

# %%
# SSIM
WIN_SIZE = 3

vp_init_model_SSIM      =           SSIM(true_v,init_v,win_size=WIN_SIZE)

vp_baseline_SSIM        = np.insert(SSIM(true_v,itervp_baseline,win_size=WIN_SIZE),0,vp_init_model_SSIM)

vp_CNN_SSIM_1x64        = np.insert(SSIM(true_v,itervp_CNN1x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_1x128       = np.insert(SSIM(true_v,itervp_CNN1x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_1x256       = np.insert(SSIM(true_v,itervp_CNN1x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_1x512       = np.insert(SSIM(true_v,itervp_CNN1x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_2x64        = np.insert(SSIM(true_v,itervp_CNN2x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_2x128       = np.insert(SSIM(true_v,itervp_CNN2x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_2x256       = np.insert(SSIM(true_v,itervp_CNN2x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_2x512       = np.insert(SSIM(true_v,itervp_CNN2x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_3x64        = np.insert(SSIM(true_v,itervp_CNN3x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_3x128       = np.insert(SSIM(true_v,itervp_CNN3x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_3x256       = np.insert(SSIM(true_v,itervp_CNN3x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_3x512       = np.insert(SSIM(true_v,itervp_CNN3x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_4x64        = np.insert(SSIM(true_v,itervp_CNN4x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_4x128       = np.insert(SSIM(true_v,itervp_CNN4x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_4x256       = np.insert(SSIM(true_v,itervp_CNN4x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)

vp_MLP_SSIM_2x100       = np.insert(SSIM(true_v,itervp_MLP2x100,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_MLP_SSIM_2x1000      = np.insert(SSIM(true_v,itervp_MLP2x1000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_2x2000      = np.insert(SSIM(true_v,itervp_MLP2x2000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_2x3000      = np.insert(SSIM(true_v,itervp_MLP2x3000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_3x100       = np.insert(SSIM(true_v,itervp_MLP3x100,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_MLP_SSIM_3x1000      = np.insert(SSIM(true_v,itervp_MLP3x1000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_3x2000      = np.insert(SSIM(true_v,itervp_MLP3x2000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_3x3000      = np.insert(SSIM(true_v,itervp_MLP3x3000,win_size=WIN_SIZE),0,vp_init_model_SSIM)

vp_Unet_SSIM_1x64       = np.insert(SSIM(true_v,itervp_Unet1x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_1x128      = np.insert(SSIM(true_v,itervp_Unet1x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_1x256      = np.insert(SSIM(true_v,itervp_Unet1x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_1x512      = np.insert(SSIM(true_v,itervp_Unet1x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_2x64       = np.insert(SSIM(true_v,itervp_Unet2x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_2x128      = np.insert(SSIM(true_v,itervp_Unet2x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_2x256      = np.insert(SSIM(true_v,itervp_Unet2x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_2x512      = np.insert(SSIM(true_v,itervp_Unet2x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_3x64       = np.insert(SSIM(true_v,itervp_Unet3x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_3x128      = np.insert(SSIM(true_v,itervp_Unet3x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_3x256      = np.insert(SSIM(true_v,itervp_Unet3x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_3x512      = np.insert(SSIM(true_v,itervp_Unet3x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_4x64       = np.insert(SSIM(true_v,itervp_Unet4x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_4x128      = np.insert(SSIM(true_v,itervp_Unet4x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_4x256      = np.insert(SSIM(true_v,itervp_Unet4x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)

# %%
print("{:.2f} {:.2f} {:.2f} {:.2f}".format(np.min(iterloss_baseline),np.min(vp_baseline_MAPE),np.max(vp_baseline_SSIM),np.max(vp_baseline_SNR)))

# %%
# data
CNN_data_loss_v = np.array([
    iterloss_CNN1x64, iterloss_CNN1x128, iterloss_CNN1x256, iterloss_CNN1x512,
    iterloss_CNN2x64, iterloss_CNN2x128, iterloss_CNN2x256, iterloss_CNN2x512,
    iterloss_CNN3x64, iterloss_CNN3x128, iterloss_CNN3x256, iterloss_CNN3x512,
    # iterloss_CNN4x64, iterloss_CNN4x128, iterloss_CNN4x256
])

MLP_data_loss_v = np.array([
    iterloss_MLP2x100, iterloss_MLP2x1000, iterloss_MLP2x2000,iterloss_MLP2x3000,
    iterloss_MLP3x100, iterloss_MLP3x1000, iterloss_MLP3x2000,
])

Unet_data_loss_v = np.array([
    iterloss_Unet1x64, iterloss_Unet1x128, iterloss_Unet1x256,iterloss_Unet1x512,
    iterloss_Unet2x64, iterloss_Unet2x128, iterloss_Unet2x256, # iterloss_Unet2x512,
    iterloss_Unet3x64, iterloss_Unet3x128, # iterloss_Unet3x256,iterloss_Unet3x512,
])

# mape
CNN_MAPE_v = np.array([
    vp_CNN_MAPE_1x64, vp_CNN_MAPE_1x128, vp_CNN_MAPE_1x256,vp_CNN_MAPE_1x512,
    vp_CNN_MAPE_2x64, vp_CNN_MAPE_2x128, vp_CNN_MAPE_2x256,vp_CNN_MAPE_2x512,
    vp_CNN_MAPE_3x64, vp_CNN_MAPE_3x128, vp_CNN_MAPE_3x256,vp_CNN_MAPE_3x512,
    # vp_CNN_MAPE_4x64, vp_CNN_MAPE_4x128, vp_CNN_MAPE_4x256,
])

MLP_MAPE_v = np.array([
    vp_MLP_MAPE_2x100, vp_MLP_MAPE_2x1000, vp_MLP_MAPE_2x2000,vp_MLP_MAPE_2x3000,
    vp_MLP_MAPE_3x100, vp_MLP_MAPE_3x1000, vp_MLP_MAPE_3x2000,
])

Unet_MAPE_v = np.array([
    vp_Unet_MAPE_1x64, vp_Unet_MAPE_1x128, vp_Unet_MAPE_1x256,vp_Unet_MAPE_1x512,
    vp_Unet_MAPE_2x64, vp_Unet_MAPE_2x128, vp_Unet_MAPE_2x256,# vp_Unet_MAPE_2x512,
    vp_Unet_MAPE_3x64, vp_Unet_MAPE_3x128, # vp_Unet_MAPE_3x256,vp_Unet_MAPE_3x512,
])

# snr
CNN_SNR_v = np.array([
    vp_CNN_SNR_1x64, vp_CNN_SNR_1x128, vp_CNN_SNR_1x256,vp_CNN_SNR_1x512,
    vp_CNN_SNR_2x64, vp_CNN_SNR_2x128, vp_CNN_SNR_2x256,vp_CNN_SNR_2x512,
    vp_CNN_SNR_3x64, vp_CNN_SNR_3x128, vp_CNN_SNR_3x256,vp_CNN_SNR_3x512,
    # vp_CNN_SNR_4x64, vp_CNN_SNR_4x128, vp_CNN_SNR_4x256
])

MLP_SNR_v = np.array([
    vp_MLP_SNR_2x100, vp_MLP_SNR_2x1000, vp_MLP_SNR_2x2000,vp_MLP_SNR_2x3000,
    vp_MLP_SNR_3x100, vp_MLP_SNR_3x1000, vp_MLP_SNR_3x2000,
])

Unet_SNR_v = np.array([
    vp_Unet_SNR_1x64, vp_Unet_SNR_1x128, vp_Unet_SNR_1x256,vp_Unet_SNR_1x512,
    vp_Unet_SNR_2x64, vp_Unet_SNR_2x128, vp_Unet_SNR_2x256,# vp_Unet_SNR_2x512,
    vp_Unet_SNR_3x64, vp_Unet_SNR_3x128, # vp_Unet_SNR_3x256,vp_Unet_SNR_3x512,
])

# ssim
CNN_SSIM_v = np.array([
    vp_CNN_SSIM_1x64, vp_CNN_SSIM_1x128, vp_CNN_SSIM_1x256,vp_CNN_SSIM_1x512,
    vp_CNN_SSIM_2x64, vp_CNN_SSIM_2x128, vp_CNN_SSIM_2x256,vp_CNN_SSIM_2x512,
    vp_CNN_SSIM_3x64, vp_CNN_SSIM_3x128, vp_CNN_SSIM_3x256,vp_CNN_SSIM_3x512,
    # vp_CNN_SSIM_4x64, vp_CNN_SSIM_4x128, vp_CNN_SSIM_4x256
])

MLP_SSIM_v = np.array([
    vp_MLP_SSIM_2x100, vp_MLP_SSIM_2x1000, vp_MLP_SSIM_2x2000,vp_MLP_SSIM_2x3000,
    vp_MLP_SSIM_3x100, vp_MLP_SSIM_3x1000, vp_MLP_SSIM_3x2000,
])

Unet_SSIM_v = np.array([
    vp_Unet_SSIM_1x64, vp_Unet_SSIM_1x128, vp_Unet_SSIM_1x256,vp_Unet_SSIM_1x512,
    vp_Unet_SSIM_2x64, vp_Unet_SSIM_2x128, vp_Unet_SSIM_2x256,# vp_Unet_SSIM_2x512,
    vp_Unet_SSIM_3x64, # vp_Unet_SSIM_3x128, vp_Unet_SSIM_3x256,vp_Unet_SSIM_3x512,
])


print("{:.2f} {:.2f} {:.2f}".format(np.min(Unet_data_loss_v[:,-1].min()), np.min(MLP_data_loss_v[:,-1].min()), np.min(CNN_data_loss_v[:,-1].min())  ))
print("{:.2f} {:.2f} {:.2f}".format(np.min(Unet_MAPE_v[:,-1].min())     , np.min(MLP_MAPE_v[:,-1].min())     , np.min(CNN_MAPE_v[:,-1].min())       ))
print("{:.2f} {:.2f} {:.2f}".format(np.max(Unet_SSIM_v[:,-1].max())     , np.max(MLP_SSIM_v[:,-1].max())     , np.max(CNN_SSIM_v[:,-1].max())       ))
print("{:.2f} {:.2f} {:.2f}".format(np.max(Unet_SNR_v[:,-1].max())      , np.max(MLP_SNR_v[:,-1].max())      , np.max(CNN_SNR_v[:,-1].max())        ))

print(np.argmin(CNN_MAPE_v.min(axis=1)),np.argmin(MLP_MAPE_v.min(axis=1)),np.argmin(Unet_MAPE_v.min(axis=1)))

select_model = 5

CNN_data_loss_v = np.sort(CNN_data_loss_v,axis=0)
MLP_data_loss_v = np.sort(MLP_data_loss_v,axis=0)
Unet_data_loss_v = np.sort(Unet_data_loss_v,axis=0)
CNN_data_loss_v = CNN_data_loss_v[:select_model,:]
MLP_data_loss_v = MLP_data_loss_v[:select_model,:]
Unet_data_loss_v = Unet_data_loss_v[:select_model,:]


CNN_MAPE_v = np.sort(CNN_MAPE_v,axis=0)
MLP_MAPE_v = np.sort(MLP_MAPE_v,axis=0)
Unet_MAPE_v = np.sort(Unet_MAPE_v,axis=0)
CNN_MAPE_v = CNN_MAPE_v[:select_model,:]
MLP_MAPE_v = MLP_MAPE_v[:select_model,:]
Unet_MAPE_v = Unet_MAPE_v[:select_model,:]

CNN_SNR_v  = np.sort(CNN_SNR_v,axis=0)[::-1]
MLP_SNR_v  = np.sort(MLP_SNR_v,axis=0)[::-1]
Unet_SNR_v = np.sort(Unet_SNR_v,axis=0)[::-1]
CNN_SNR_v  = CNN_SNR_v[:select_model,:]
MLP_SNR_v  = MLP_SNR_v[:select_model,:]
Unet_SNR_v = Unet_SNR_v[:select_model,:]

CNN_SSIM_v  = np.sort(CNN_SSIM_v,axis=0)[::-1]
MLP_SSIM_v  = np.sort(MLP_SSIM_v,axis=0)[::-1]
Unet_SSIM_v = np.sort(Unet_SSIM_v,axis=0)[::-1]
CNN_SSIM_v  = CNN_SSIM_v[:select_model,:]
MLP_SSIM_v  = MLP_SSIM_v[:select_model,:]
Unet_SSIM_v = Unet_SSIM_v[:select_model,:]

# %% [markdown]
# ## dv

# %%
base_path = "/home/bingxing2/ailab/scxlab0055/project/04_Inversion/ADFWI-github/examples/DR-FWI/reparameterization-strategy/Marmousi2-nowater-dv/data"

itervp_baseline      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-baseline/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN1x512      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN2x512      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN3x512      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN4x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-4x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN4x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-4x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN4x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-4x256/iter_vp.npz"))["data"][:MAX_ITER]


iterloss_baseline    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-baseline/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x64     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x128    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x256    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN1x512    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-1x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x64     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x128    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x256    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN2x512    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-2x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x64     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x128    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x256    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN3x512    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-3x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN4x64     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-4x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN4x128    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-4x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_CNN4x256    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-CNN-4x256/iter_loss.npz"))["data"][:MAX_ITER]

# %%
itervp_MLP2x100      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x100/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP2x1000     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x1000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP2x2000     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x2000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP2x3000     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x3000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x100      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x100/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x1000     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x1000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x2000     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x2000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP3x3000     = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x3000/iter_vp.npz"))["data"][:MAX_ITER]


iterloss_MLP2x100    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x100/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP2x1000   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x1000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP2x2000   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x2000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP2x3000   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-2x3000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x100    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x100/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x1000   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x1000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x2000   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x2000/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_MLP3x3000   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-MLP-3x3000/iter_loss.npz"))["data"][:MAX_ITER]

# %%
itervp_Unet1x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet1x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet1x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet1x512      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet2x512      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet3x512      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x512/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet4x64       = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-4x64/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet4x128      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-4x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet4x256      = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-4x256/iter_vp.npz"))["data"][:MAX_ITER]

iterloss_Unet1x64    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet1x128   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet1x256   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet1x512   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-1x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x64    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x128   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x256   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet2x512   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-2x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x64    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x128   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x256   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x256/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet3x512   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-3x512/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet4x64    = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-4x64/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet4x128   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-4x128/iter_loss.npz"))["data"][:MAX_ITER]
iterloss_Unet4x256   = np.load(os.path.join(base_path,"GC-1_-1/inversion-vp-Unet-4x256/iter_loss.npz"))["data"][:MAX_ITER]

# %%
# MAPE
vp_init_model_MAPE      =           MAPE(true_v,init_v)

vp_baseline_MAPE        = np.insert(MAPE(true_v,itervp_baseline),0,vp_init_model_MAPE)

vp_CNN_MAPE_1x64        = np.insert(MAPE(true_v,itervp_CNN1x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_1x128       = np.insert(MAPE(true_v,itervp_CNN1x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_1x256       = np.insert(MAPE(true_v,itervp_CNN1x256),0,vp_init_model_MAPE)
vp_CNN_MAPE_1x512       = np.insert(MAPE(true_v,itervp_CNN1x512),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x64        = np.insert(MAPE(true_v,itervp_CNN2x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x128       = np.insert(MAPE(true_v,itervp_CNN2x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x256       = np.insert(MAPE(true_v,itervp_CNN2x256),0,vp_init_model_MAPE)
vp_CNN_MAPE_2x512       = np.insert(MAPE(true_v,itervp_CNN2x512),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x64        = np.insert(MAPE(true_v,itervp_CNN3x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x128       = np.insert(MAPE(true_v,itervp_CNN3x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x256       = np.insert(MAPE(true_v,itervp_CNN3x256),0,vp_init_model_MAPE)
vp_CNN_MAPE_3x512       = np.insert(MAPE(true_v,itervp_CNN3x512),0,vp_init_model_MAPE)
vp_CNN_MAPE_4x64        = np.insert(MAPE(true_v,itervp_CNN4x64),0,vp_init_model_MAPE)
vp_CNN_MAPE_4x128       = np.insert(MAPE(true_v,itervp_CNN4x128),0,vp_init_model_MAPE)
vp_CNN_MAPE_4x256       = np.insert(MAPE(true_v,itervp_CNN4x256),0,vp_init_model_MAPE)

vp_MLP_MAPE_2x100       = np.insert(MAPE(true_v,itervp_MLP2x100),0,vp_init_model_MAPE)
vp_MLP_MAPE_2x1000      = np.insert(MAPE(true_v,itervp_MLP2x1000),0,vp_init_model_MAPE)
vp_MLP_MAPE_2x2000      = np.insert(MAPE(true_v,itervp_MLP2x2000),0,vp_init_model_MAPE)
vp_MLP_MAPE_2x3000      = np.insert(MAPE(true_v,itervp_MLP2x3000),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x100       = np.insert(MAPE(true_v,itervp_MLP3x100),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x1000      = np.insert(MAPE(true_v,itervp_MLP3x1000),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x2000      = np.insert(MAPE(true_v,itervp_MLP3x2000),0,vp_init_model_MAPE)
vp_MLP_MAPE_3x3000      = np.insert(MAPE(true_v,itervp_MLP3x3000),0,vp_init_model_MAPE)


vp_Unet_MAPE_1x64        = np.insert(MAPE(true_v,itervp_Unet1x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_1x128       = np.insert(MAPE(true_v,itervp_Unet1x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_1x256       = np.insert(MAPE(true_v,itervp_Unet1x256),0,vp_init_model_MAPE)
vp_Unet_MAPE_1x512       = np.insert(MAPE(true_v,itervp_Unet1x512),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x64        = np.insert(MAPE(true_v,itervp_Unet2x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x128       = np.insert(MAPE(true_v,itervp_Unet2x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x256       = np.insert(MAPE(true_v,itervp_Unet2x256),0,vp_init_model_MAPE)
vp_Unet_MAPE_2x512       = np.insert(MAPE(true_v,itervp_Unet2x512),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x64        = np.insert(MAPE(true_v,itervp_Unet3x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x128       = np.insert(MAPE(true_v,itervp_Unet3x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x256       = np.insert(MAPE(true_v,itervp_Unet3x256),0,vp_init_model_MAPE)
vp_Unet_MAPE_3x512       = np.insert(MAPE(true_v,itervp_Unet3x512),0,vp_init_model_MAPE)
vp_Unet_MAPE_4x64        = np.insert(MAPE(true_v,itervp_Unet4x64),0,vp_init_model_MAPE)
vp_Unet_MAPE_4x128       = np.insert(MAPE(true_v,itervp_Unet4x128),0,vp_init_model_MAPE)
vp_Unet_MAPE_4x256       = np.insert(MAPE(true_v,itervp_Unet4x256),0,vp_init_model_MAPE)

# %%
# SNR
vp_init_model_SNR      =           SNR(true_v,init_v)

vp_baseline_SNR        = np.insert(SNR(true_v,itervp_baseline),0,vp_init_model_SNR)

vp_CNN_SNR_1x64        = np.insert(SNR(true_v,itervp_CNN1x64),0 ,vp_init_model_SNR)
vp_CNN_SNR_1x128       = np.insert(SNR(true_v,itervp_CNN1x128),0,vp_init_model_SNR)
vp_CNN_SNR_1x256       = np.insert(SNR(true_v,itervp_CNN1x256),0,vp_init_model_SNR)
vp_CNN_SNR_1x512       = np.insert(SNR(true_v,itervp_CNN1x512),0,vp_init_model_SNR)
vp_CNN_SNR_2x64        = np.insert(SNR(true_v,itervp_CNN2x64),0 ,vp_init_model_SNR)
vp_CNN_SNR_2x128       = np.insert(SNR(true_v,itervp_CNN2x128),0,vp_init_model_SNR)
vp_CNN_SNR_2x256       = np.insert(SNR(true_v,itervp_CNN2x256),0,vp_init_model_SNR)
vp_CNN_SNR_2x512       = np.insert(SNR(true_v,itervp_CNN2x512),0,vp_init_model_SNR)
vp_CNN_SNR_3x64        = np.insert(SNR(true_v,itervp_CNN3x64),0 ,vp_init_model_SNR)
vp_CNN_SNR_3x128       = np.insert(SNR(true_v,itervp_CNN3x128),0,vp_init_model_SNR)
vp_CNN_SNR_3x256       = np.insert(SNR(true_v,itervp_CNN3x256),0,vp_init_model_SNR)
vp_CNN_SNR_3x512       = np.insert(SNR(true_v,itervp_CNN3x512),0,vp_init_model_SNR)
vp_CNN_SNR_4x64        = np.insert(SNR(true_v,itervp_CNN4x64),0,vp_init_model_SNR)
vp_CNN_SNR_4x128       = np.insert(SNR(true_v,itervp_CNN4x128),0,vp_init_model_SNR)
vp_CNN_SNR_4x256       = np.insert(SNR(true_v,itervp_CNN4x256),0,vp_init_model_SNR)


vp_MLP_SNR_2x100       = np.insert(SNR(true_v,itervp_MLP2x100) ,0,vp_init_model_SNR)
vp_MLP_SNR_2x1000      = np.insert(SNR(true_v,itervp_MLP2x1000),0,vp_init_model_SNR)
vp_MLP_SNR_2x2000      = np.insert(SNR(true_v,itervp_MLP2x2000),0,vp_init_model_SNR)
vp_MLP_SNR_2x3000      = np.insert(SNR(true_v,itervp_MLP2x3000),0,vp_init_model_SNR)
vp_MLP_SNR_3x100       = np.insert(SNR(true_v,itervp_MLP3x100) ,0,vp_init_model_SNR)
vp_MLP_SNR_3x1000      = np.insert(SNR(true_v,itervp_MLP3x1000),0,vp_init_model_SNR)
vp_MLP_SNR_3x2000      = np.insert(SNR(true_v,itervp_MLP3x2000),0,vp_init_model_SNR)
vp_MLP_SNR_3x3000      = np.insert(SNR(true_v,itervp_MLP3x3000),0,vp_init_model_SNR)


vp_Unet_SNR_1x64        = np.insert(SNR(true_v,itervp_Unet1x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_1x128       = np.insert(SNR(true_v,itervp_Unet1x128),0,vp_init_model_SNR)
vp_Unet_SNR_1x256       = np.insert(SNR(true_v,itervp_Unet1x256),0,vp_init_model_SNR)
vp_Unet_SNR_1x512       = np.insert(SNR(true_v,itervp_Unet1x512),0,vp_init_model_SNR)
vp_Unet_SNR_2x64        = np.insert(SNR(true_v,itervp_Unet2x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_2x128       = np.insert(SNR(true_v,itervp_Unet2x128),0,vp_init_model_SNR)
vp_Unet_SNR_2x256       = np.insert(SNR(true_v,itervp_Unet2x256),0,vp_init_model_SNR)
vp_Unet_SNR_2x512       = np.insert(SNR(true_v,itervp_Unet2x512),0,vp_init_model_SNR)
vp_Unet_SNR_3x64        = np.insert(SNR(true_v,itervp_Unet3x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_3x128       = np.insert(SNR(true_v,itervp_Unet3x128),0,vp_init_model_SNR)
vp_Unet_SNR_3x256       = np.insert(SNR(true_v,itervp_Unet3x256),0,vp_init_model_SNR)
vp_Unet_SNR_3x512       = np.insert(SNR(true_v,itervp_Unet3x512),0,vp_init_model_SNR)
vp_Unet_SNR_4x64        = np.insert(SNR(true_v,itervp_Unet4x64) ,0,vp_init_model_SNR)
vp_Unet_SNR_4x128       = np.insert(SNR(true_v,itervp_Unet4x128),0,vp_init_model_SNR)
vp_Unet_SNR_4x256       = np.insert(SNR(true_v,itervp_Unet4x256),0,vp_init_model_SNR)

# %%
# SSIM
WIN_SIZE = 3

vp_init_model_SSIM      =           SSIM(true_v,init_v,win_size=WIN_SIZE)

vp_baseline_SSIM        = np.insert(SSIM(true_v,itervp_baseline,win_size=WIN_SIZE),0,vp_init_model_SSIM)

vp_CNN_SSIM_1x64        = np.insert(SSIM(true_v,itervp_CNN1x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_1x128       = np.insert(SSIM(true_v,itervp_CNN1x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_1x256       = np.insert(SSIM(true_v,itervp_CNN1x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_1x512       = np.insert(SSIM(true_v,itervp_CNN1x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_2x64        = np.insert(SSIM(true_v,itervp_CNN2x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_2x128       = np.insert(SSIM(true_v,itervp_CNN2x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_2x256       = np.insert(SSIM(true_v,itervp_CNN2x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_2x512       = np.insert(SSIM(true_v,itervp_CNN2x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_3x64        = np.insert(SSIM(true_v,itervp_CNN3x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_3x128       = np.insert(SSIM(true_v,itervp_CNN3x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_3x256       = np.insert(SSIM(true_v,itervp_CNN3x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_3x512       = np.insert(SSIM(true_v,itervp_CNN3x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_4x64        = np.insert(SSIM(true_v,itervp_CNN4x64,win_size=WIN_SIZE),0 ,vp_init_model_SSIM)
vp_CNN_SSIM_4x128       = np.insert(SSIM(true_v,itervp_CNN4x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_CNN_SSIM_4x256       = np.insert(SSIM(true_v,itervp_CNN4x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)

vp_MLP_SSIM_2x100       = np.insert(SSIM(true_v,itervp_MLP2x100,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_MLP_SSIM_2x1000      = np.insert(SSIM(true_v,itervp_MLP2x1000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_2x2000      = np.insert(SSIM(true_v,itervp_MLP2x2000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_2x3000      = np.insert(SSIM(true_v,itervp_MLP2x3000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_3x100       = np.insert(SSIM(true_v,itervp_MLP3x100,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_MLP_SSIM_3x1000      = np.insert(SSIM(true_v,itervp_MLP3x1000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_3x2000      = np.insert(SSIM(true_v,itervp_MLP3x2000,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_MLP_SSIM_3x3000      = np.insert(SSIM(true_v,itervp_MLP3x3000,win_size=WIN_SIZE),0,vp_init_model_SSIM)

vp_Unet_SSIM_1x64       = np.insert(SSIM(true_v,itervp_Unet1x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_1x128      = np.insert(SSIM(true_v,itervp_Unet1x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_1x256      = np.insert(SSIM(true_v,itervp_Unet1x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_1x512      = np.insert(SSIM(true_v,itervp_Unet1x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_2x64       = np.insert(SSIM(true_v,itervp_Unet2x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_2x128      = np.insert(SSIM(true_v,itervp_Unet2x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_2x256      = np.insert(SSIM(true_v,itervp_Unet2x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_2x512      = np.insert(SSIM(true_v,itervp_Unet2x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_3x64       = np.insert(SSIM(true_v,itervp_Unet3x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_3x128      = np.insert(SSIM(true_v,itervp_Unet3x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_3x256      = np.insert(SSIM(true_v,itervp_Unet3x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_3x512      = np.insert(SSIM(true_v,itervp_Unet3x512,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_4x64       = np.insert(SSIM(true_v,itervp_Unet4x64,win_size=WIN_SIZE) ,0,vp_init_model_SSIM)
vp_Unet_SSIM_4x128      = np.insert(SSIM(true_v,itervp_Unet4x128,win_size=WIN_SIZE),0,vp_init_model_SSIM)
vp_Unet_SSIM_4x256      = np.insert(SSIM(true_v,itervp_Unet4x256,win_size=WIN_SIZE),0,vp_init_model_SSIM)

# %%
# data
CNN_data_loss_dv = np.array([
    iterloss_CNN1x64, iterloss_CNN1x128, iterloss_CNN1x256, iterloss_CNN1x512,
    iterloss_CNN2x64, iterloss_CNN2x128, iterloss_CNN2x256, iterloss_CNN2x512,
    iterloss_CNN3x64, iterloss_CNN3x128, iterloss_CNN3x256, iterloss_CNN3x512,
    # iterloss_CNN4x64, iterloss_CNN4x128, iterloss_CNN4x256
])

MLP_data_loss_dv = np.array([
    iterloss_MLP2x100, iterloss_MLP2x1000, iterloss_MLP2x2000,iterloss_MLP2x3000,
    iterloss_MLP3x100, iterloss_MLP3x1000, iterloss_MLP3x2000,
])

Unet_data_loss_dv = np.array([
    iterloss_Unet1x64, iterloss_Unet1x128, iterloss_Unet1x256,iterloss_Unet1x512,
    iterloss_Unet2x64, iterloss_Unet2x128, iterloss_Unet2x256, # iterloss_Unet2x512,
    iterloss_Unet3x64, iterloss_Unet3x128, # iterloss_Unet3x256,iterloss_Unet3x512,
])

# mape
CNN_MAPE_dv = np.array([
    vp_CNN_MAPE_1x64, vp_CNN_MAPE_1x128, vp_CNN_MAPE_1x256, vp_CNN_MAPE_1x512,
    vp_CNN_MAPE_2x64, vp_CNN_MAPE_2x128, vp_CNN_MAPE_2x256, vp_CNN_MAPE_2x512,
    vp_CNN_MAPE_3x64, vp_CNN_MAPE_3x128, vp_CNN_MAPE_3x256, vp_CNN_MAPE_3x512,
    # vp_CNN_MAPE_4x64, vp_CNN_MAPE_4x128, vp_CNN_MAPE_4x256,
])

MLP_MAPE_dv = np.array([
    vp_MLP_MAPE_2x100, vp_MLP_MAPE_2x1000, vp_MLP_MAPE_2x2000,vp_MLP_MAPE_2x3000,
    vp_MLP_MAPE_3x100, vp_MLP_MAPE_3x1000, vp_MLP_MAPE_3x2000,
])

Unet_MAPE_dv = np.array([
    vp_Unet_MAPE_1x64, vp_Unet_MAPE_1x128, vp_Unet_MAPE_1x256,vp_Unet_MAPE_1x512,
    vp_Unet_MAPE_2x64, vp_Unet_MAPE_2x128, vp_Unet_MAPE_2x256,# vp_Unet_MAPE_2x512,
    vp_Unet_MAPE_3x64, vp_Unet_MAPE_3x128, # vp_Unet_MAPE_3x256,vp_Unet_MAPE_3x512,
])

# snr
CNN_SNR_dv = np.array([
    vp_CNN_SNR_1x64, vp_CNN_SNR_1x128, vp_CNN_SNR_1x256, vp_CNN_SNR_1x512,
    vp_CNN_SNR_2x64, vp_CNN_SNR_2x128, vp_CNN_SNR_2x256, vp_CNN_SNR_2x512,
    vp_CNN_SNR_3x64, vp_CNN_SNR_3x128, vp_CNN_SNR_3x256, vp_CNN_SNR_3x512,
    # vp_CNN_SNR_4x64, vp_CNN_SNR_4x128, vp_CNN_SNR_4x256
])

MLP_SNR_dv = np.array([
    vp_MLP_SNR_2x100, vp_MLP_SNR_2x1000, vp_MLP_SNR_2x2000,vp_MLP_SNR_2x3000,
    vp_MLP_SNR_3x100, vp_MLP_SNR_3x1000, vp_MLP_SNR_3x2000,
])

Unet_SNR_dv = np.array([
    vp_Unet_SNR_1x64, vp_Unet_SNR_1x128, vp_Unet_SNR_1x256, vp_Unet_SNR_1x512,
    vp_Unet_SNR_2x64, vp_Unet_SNR_2x128, vp_Unet_SNR_2x256,# vp_Unet_SNR_2x512,
    vp_Unet_SNR_3x64, vp_Unet_SNR_3x128, # vp_Unet_SNR_3x256,vp_Unet_SNR_3x512,
])

# ssim
CNN_SSIM_dv = np.array([
    vp_CNN_SSIM_1x64, vp_CNN_SSIM_1x128, vp_CNN_SSIM_1x256,# vp_CNN_SSIM_1x512,
    vp_CNN_SSIM_2x64, vp_CNN_SSIM_2x128, vp_CNN_SSIM_2x256,vp_CNN_SSIM_2x512,
    vp_CNN_SSIM_3x64, vp_CNN_SSIM_3x128, vp_CNN_SSIM_3x256,vp_CNN_SSIM_3x512,
    # vp_CNN_SSIM_4x64, vp_CNN_SSIM_4x128, vp_CNN_SSIM_4x256
])

MLP_SSIM_dv = np.array([
    vp_MLP_SSIM_2x100, vp_MLP_SSIM_2x1000, vp_MLP_SSIM_2x2000,vp_MLP_SSIM_2x3000,
    vp_MLP_SSIM_3x100, vp_MLP_SSIM_3x1000, vp_MLP_SSIM_3x2000,
])

Unet_SSIM_dv = np.array([
    vp_Unet_SSIM_1x64, vp_Unet_SSIM_1x128, vp_Unet_SSIM_1x256,vp_Unet_SSIM_1x512,
    vp_Unet_SSIM_2x64, vp_Unet_SSIM_2x128, vp_Unet_SSIM_2x256,# vp_Unet_SSIM_2x512,
    vp_Unet_SSIM_3x64, # vp_Unet_SSIM_3x128, vp_Unet_SSIM_3x256,vp_Unet_SSIM_3x512,
])

print("{:.2f} {:.2f} {:.2f}".format(np.min(Unet_data_loss_dv[:,-1].min()), np.min(MLP_data_loss_dv[:,-1].min()), np.min(CNN_data_loss_dv[:,-1].min())  ))
print("{:.2f} {:.2f} {:.2f}".format(np.min(Unet_MAPE_dv[:,-1].min())     , np.min(MLP_MAPE_dv[:,-1].min())     , np.min(CNN_MAPE_dv[:,-1].min())       ))
print("{:.2f} {:.2f} {:.2f}".format(np.max(Unet_SSIM_dv[:,-1].max())     , np.max(MLP_SSIM_dv[:,-1].max())     , np.max(CNN_SSIM_dv[:,-1].max())       ))
print("{:.2f} {:.2f} {:.2f}".format(np.max(Unet_SNR_dv[:,-1].max())      , np.max(MLP_SNR_dv[:,-1].max())      , np.max(CNN_SNR_dv[:,-1].max())        ))

print(np.argmin(CNN_MAPE_dv.min(axis=1)),np.argmin(MLP_MAPE_dv.min(axis=1)),np.argmin(Unet_MAPE_dv.min(axis=1)))

select_model = 5

CNN_data_loss_dv = np.sort(CNN_data_loss_dv,axis=0)
MLP_data_loss_dv = np.sort(MLP_data_loss_dv,axis=0)
Unet_data_loss_dv = np.sort(Unet_data_loss_dv,axis=0)
CNN_data_loss_dv = CNN_data_loss_dv[:select_model,:]
MLP_data_loss_dv = MLP_data_loss_dv[:select_model,:]
Unet_data_loss_dv = Unet_data_loss_dv[:select_model,:]


CNN_MAPE_dv = np.sort(CNN_MAPE_dv,axis=0)
MLP_MAPE_dv = np.sort(MLP_MAPE_dv,axis=0)
Unet_MAPE_dv = np.sort(Unet_MAPE_dv,axis=0)
CNN_MAPE_dv = CNN_MAPE_dv[:select_model,:]
MLP_MAPE_dv = MLP_MAPE_dv[:select_model,:]
Unet_MAPE_dv = Unet_MAPE_dv[:select_model,:]

CNN_SNR_dv  = np.sort(CNN_SNR_dv,axis=0)[::-1]
MLP_SNR_dv  = np.sort(MLP_SNR_dv,axis=0)[::-1]
Unet_SNR_dv = np.sort(Unet_SNR_dv,axis=0)[::-1]
CNN_SNR_dv  = CNN_SNR_dv[:select_model,:]
MLP_SNR_dv  = MLP_SNR_dv[:select_model,:]
Unet_SNR_dv = Unet_SNR_dv[:select_model,:]

CNN_SSIM_dv  = np.sort(CNN_SSIM_dv,axis=0)[::-1]
MLP_SSIM_dv  = np.sort(MLP_SSIM_dv,axis=0)[::-1]
Unet_SSIM_dv = np.sort(Unet_SSIM_dv,axis=0)[::-1]
CNN_SSIM_dv  = CNN_SSIM_dv[:select_model,:]
MLP_SSIM_dv  = MLP_SSIM_dv[:select_model,:]
Unet_SSIM_dv = Unet_SSIM_dv[:select_model,:]

# %% [markdown]
# ## Article Figure-Misfit

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.lines import Line2D
plt.rcParams['svg.fonttype'] = 'none'

palette = sns.color_palette("deep")
colors = {
    "Traditional FWI": "#4D4D4D",  # Dark gray
    "cnn_dv": palette[0],    # Blue for CNN-v
    "cnn_v": sns.dark_palette(palette[0], 2)[1],  # Darker blue for CNN-dv
    "mlp_dv": palette[1],    # Green for MLP-v
    "mlp_v": sns.dark_palette(palette[1], 2)[1],  # Darker green for MLP-dv
    "unet_dv": palette[2],   # Purple for Unet-v
    "unet_v": sns.dark_palette(palette[2], 2)[1]  # Darker purple for Unet-dv
}

# Set up the figure
fig = plt.figure(figsize=(12, 8))

#########################################################################################
# First subplot: Data Residual
ax1 = plt.subplot(221)
# Create inset zoom-in
axins = ax1.inset_axes([0.35, 0.4, 0.4, 0.3])  # (x_pos, y_pos, width, height)
axins.set_xlim(200, 300)
axins.set_ylim(-8100, -7400)

sparse_num = 2
xlist = np.arange(MAX_ITER)[::sparse_num]

baseline_losses = iterloss_baseline[::sparse_num]
cnn_mean  = np.mean(CNN_data_loss_v, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_data_loss_v, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_data_loss_v, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_data_loss_v, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_data_loss_v, axis=0)[::sparse_num]
unet_std  = np.std(Unet_data_loss_v, axis=0)[::sparse_num]

ax1.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax1.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax1.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax1.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

axins.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
axins.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.05)
axins.plot(xlist, cnn_mean, linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
axins.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.05)
axins.plot(xlist, mlp_mean, linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
axins.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.05)
axins.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# ----------------------------------------------------------
cnn_mean  = np.mean(CNN_data_loss_dv, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_data_loss_dv, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_data_loss_dv, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_data_loss_dv, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_data_loss_dv, axis=0)[::sparse_num]
unet_std  = np.std(Unet_data_loss_dv, axis=0)[::sparse_num]

ax1.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax1.plot(xlist, cnn_mean,  linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax1.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax1.plot(xlist, unet_mean,  linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)

axins.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.05)
axins.plot(xlist, cnn_mean, linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
axins.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.05)
axins.plot(xlist, mlp_mean, linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
axins.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.05)
axins.plot(xlist, unet_mean, linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


ax1.set_ylabel('Global-Correlation Misfits', fontsize=14)
ax1.set_xticklabels([])
ax1.tick_params(axis="x", which="both", length=0)
ax1.grid(True, linestyle='--', alpha=0.6)

axins.set_xticks([])
axins.set_yticks([])

ax1.indicate_inset_zoom(axins, edgecolor="black")

#######################################################
# Second subplot: Model Residual
ax2 = plt.subplot(222)

xlist = np.arange(MAX_ITER+1)[::sparse_num]
baseline_losses = vp_baseline_MAPE[::sparse_num]
cnn_mean  = np.mean(CNN_MAPE_v, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_MAPE_v, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_MAPE_v, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_MAPE_v, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_MAPE_v, axis=0)[::sparse_num]
unet_std  = np.std(Unet_MAPE_v, axis=0)[::sparse_num]

ax2.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax2.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax2.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax2.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

#-----------------------------------------------------
cnn_mean  = np.mean(CNN_MAPE_dv, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_MAPE_dv, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_MAPE_dv, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_MAPE_dv, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_MAPE_dv, axis=0)[::sparse_num]
unet_std  = np.std(Unet_MAPE_dv, axis=0)[::sparse_num]

ax2.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax2.plot(xlist, cnn_mean,  linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax2.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax2.plot(xlist, unet_mean, linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


# Improve axis style
# ax2.set_ylabel('Mean Absolute Percentage Error', fontsize=12)
ax2.set_ylabel(r'MAPE ($\downarrow$)', fontsize=14)
# ax2.set_title("Model Residual", fontsize=12)
ax2.set_xticklabels([])  # Hide x-axis labels
ax2.tick_params(axis="x", which="both", length=0)
ax2.grid(True, linestyle='--', alpha=0.6)
# ax2.legend(loc='upper right', fontsize=10)


#######################################################
# Second subplot: Model Residual
ax3 = plt.subplot(223)
xlist = np.arange(MAX_ITER+1)[::sparse_num]
baseline_losses = vp_baseline_SNR[::sparse_num]
cnn_mean  = np.mean(CNN_SNR_v, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_SNR_v, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_SNR_v, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_SNR_v, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_SNR_v, axis=0)[::sparse_num]
unet_std  = np.std(Unet_SNR_v, axis=0)[::sparse_num]

ax3.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax3.plot(xlist, cnn_mean, linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax3.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax3.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# -----------------------------------------------------------

cnn_mean  = np.mean(CNN_SNR_dv, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_SNR_dv, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_SNR_dv, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_SNR_dv, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_SNR_dv, axis=0)[::sparse_num]
unet_std  = np.std(Unet_SNR_dv, axis=0)[::sparse_num]

ax3.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax3.plot(xlist, cnn_mean, linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax3.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax3.plot(xlist, unet_mean, linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


# Improve axis style for second subplot
ax3.set_xlabel('Iterations', fontsize=15)
# ax3.set_ylabel('Signal-to-Noise Ratio', fontsize=12)
ax3.set_ylabel(r"SNR ($\uparrow$)", fontsize=14)
# ax3.set_title("Model Residual", fontsize=12)
ax3.grid(True, linestyle='--', alpha=0.6)

#######################################################
# Second subplot: Model Residual
ax4 = plt.subplot(224)
xlist = np.arange(MAX_ITER+1)[::sparse_num]
baseline_losses = vp_baseline_SSIM[::sparse_num]
cnn_mean  = np.mean(CNN_SSIM_v, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_SSIM_v, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_SSIM_v, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_SSIM_v, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_SSIM_v, axis=0)[::sparse_num]
unet_std  = np.std(Unet_SSIM_v, axis=0)[::sparse_num]

ax4.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax4.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax4.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax4.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# -------------------------------------------------------------
cnn_mean  = np.mean(CNN_SSIM_dv, axis=0)[::sparse_num]
cnn_std   = np.std(CNN_SSIM_dv, axis=0)[::sparse_num]
mlp_mean  = np.mean(MLP_SSIM_dv, axis=0)[::sparse_num]
mlp_std   = np.std(MLP_SSIM_dv, axis=0)[::sparse_num]
unet_mean = np.mean(Unet_SSIM_dv, axis=0)[::sparse_num]
unet_std  = np.std(Unet_SSIM_dv, axis=0)[::sparse_num]

ax4.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax4.plot(xlist, cnn_mean,  linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax4.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax4.plot(xlist, unet_mean,  linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


# Improve axis style for second subplot
ax4.set_xlabel('Iterations', fontsize=15)
# ax4.set_ylabel('Structural Similarity Index Meansure', fontsize=12)
ax4.set_ylabel(r'SSIM ($\uparrow$)', fontsize=14)
# ax4.set_title("Model Residual", fontsize=12)
ax4.grid(True, linestyle='--', alpha=0.6)


# -------------------------------------------------------------
ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)
ax3.tick_params(labelsize=12)
ax4.tick_params(labelsize=12)

ax1.text(-0.17, 0.95, "(a)", transform=ax1.transAxes, fontsize=14, va='bottom', ha='left')
ax2.text(-0.12, 0.95, "(b)", transform=ax2.transAxes, fontsize=14, va='bottom', ha='left')
ax3.text(-0.11, 0.95, "(c)", transform=ax3.transAxes, fontsize=14, va='bottom', ha='left')
ax4.text(-0.13, 0.95, "(d)", transform=ax4.transAxes, fontsize=14, va='bottom', ha='left')

# Adjust layout
plt.tight_layout()


# legend
ordered_labels = [
    "Traditional FWI", "", 
    "CNN-$v_p$", "CNN-$\Delta v_p$", 
    "MLP-$v_p$", "MLP-$\Delta v_p$",
    "Unet-$v_p$", "Unet-$\Delta v_p$"
]
placeholder = Line2D([0], [0], linestyle='none', label='', color='white')  # 不显示的图例项
handles, labels = ax2.get_legend_handles_labels()
label_to_handle = dict(zip(labels, handles))
label_to_handle[""] = placeholder
ordered_handles = [label_to_handle[label] for label in ordered_labels]
legend = plt.figlegend(ordered_handles, ordered_labels, loc='lower center', ncol=4, fontsize=15, frameon=False, bbox_to_anchor=(0.52, -0.12))

fig.canvas.draw()  # 确保 legend 被渲染
legend_box = legend.get_window_extent(fig.canvas.get_renderer()).transformed(fig.transFigure.inverted())

# 添加背景色框
from matplotlib.patches import FancyBboxPatch
background = FancyBboxPatch(
    (legend_box.x0 - 0.01, legend_box.y0),  # 左下角坐标
    legend_box.width + 0.01,                      # 宽度
    legend_box.height + 0.01,                     # 高度
    boxstyle="round,pad=0.01",                    # 可选的圆角样式
    transform=fig.transFigure,
    facecolor='#f8f8f8',
    edgecolor='none',
    zorder=0
)
fig.patches.append(background)

# plt.savefig("./Figures/Figure5_Architecture_and_Strategy_Marmousi2_Misfit.png",bbox_inches='tight',dpi=300)
plt.savefig("./Figures_SVG/Figure5_Architecture_and_Strategy_Marmousi2_Misfit.svg",bbox_inches='tight',format="svg")
# plt.savefig("./Figures_PDF/Figure5_Architecture_and_Strategy_Marmousi2_Misfit.pdf",bbox_inches='tight',format="pdf",dpi=600)
plt.show()

# %% [markdown]
# ## Article Figure-Velocity Model

# %%
import matplotlib.transforms as mtransforms
from scipy.interpolate import griddata
plt.rcParams['svg.fonttype'] = 'none'

def plot_vel_single_for_all(fig,ax,v,title="",MSE="",vmin=None,vmax=None,cmap = "rainbow"):
    plt.rc('font',family='Times New Roman')
    # plm = ax.pcolormesh(x_mesh, z_mesh, v,cmap=cmap,vmin=vmin,vmax=vmax)
    x = np.arange(nx*3)*dx/3/1000
    z = np.arange(nz*3)*dz/3/1000
    x_mesh_new,z_mesh_new = np.meshgrid(x,z)

    v_new = griddata((x_mesh.flatten(), z_mesh.flatten()), v.flatten(), (x_mesh_new, z_mesh_new), method='cubic')
    
    plm = ax.pcolormesh(x_mesh_new, z_mesh_new, v_new,cmap=cmap,vmin=vmin,vmax=vmax,shading="nearest")
    ax.invert_yaxis()
    ax.tick_params(labelsize = 14)
    ax.set_title(title,fontsize=14)
    ax.text(0.2,0.4,MSE,fontsize=14,c="w")
    return plm

def add_right_cax(ax, pad, width):
    axpos = ax.get_position()
    caxpos = mtransforms.Bbox.from_extents(
        axpos.x1 + pad,
        axpos.y0,
        axpos.x1 + pad + width,
        axpos.y1
    )
    cax = ax.figure.add_axes(caxpos)

    return cax

def add_bottom_cax(ax, pad, height):
    axpos = ax.get_position()
    caxpos = mtransforms.Bbox.from_extents(
        axpos.x0,
        axpos.y0 - pad - height,
        axpos.x1,
        axpos.y0 - pad
    )
    cax = ax.figure.add_axes(caxpos)
    
    return cax

def plot_vel_singleline_for_all(ax,v_true,v_init,v_inv,x_distance,title,show_xlabel=True,show_ylabel=False,show_legend=False):
    ax.plot(v_true[:,int(x_distance//dx)]/1000,  z, c='k',   linewidth=2, linestyle="-" ,label="True")
    ax.plot(v_init[:,int(x_distance//dx)]/1000,  z, c='gray',linewidth=2, linestyle="-" ,label="Init")
    ax.plot(v_inv [:,int(x_distance//dx)]/1000,  z, c='r',   linewidth=2, linestyle="--",label="Inverted")
    ax.tick_params(labelsize = 12)
    if not show_xlabel:
        ax.set_xticks([])

    if not show_ylabel:
        ax.set_yticks([])
    else:
        ax.tick_params(labelsize = 10)
    ax.invert_yaxis()
    
    if show_legend:
        ax.legend(fontsize = 12)
    ax.set_title(title,fontsize=12)

# %%
path1 = "/home/bingxing2/ailab/scxlab0055/project/04_Inversion/ADFWI-github/examples/DR-FWI/reparameterization-strategy/Marmousi2-nowater/data/GC"
path2 = "/home/bingxing2/ailab/scxlab0055/project/04_Inversion/ADFWI-github/examples/DR-FWI/reparameterization-strategy/Marmousi2-nowater-dv/data/GC-1_-1"


itervp_CNN = np.load(os.path.join(path1,"inversion-vp-CNN-2x256/iter_vp.npz"))["data"][:MAX_ITER]
itervp_CNN_diff = np.load(os.path.join(path2,"inversion-vp-CNN-3x256/iter_vp.npz"))["data"][:MAX_ITER]

itervp_MLP = np.load(os.path.join(path1,"inversion-vp-MLP-2x3000/iter_vp.npz"))["data"][:MAX_ITER]
itervp_MLP_diff = np.load(os.path.join(path2,"inversion-vp-MLP-2x3000/iter_vp.npz"))["data"][:MAX_ITER]

itervp_Unet = np.load(os.path.join(path1,"inversion-vp-Unet-2x128/iter_vp.npz"))["data"][:MAX_ITER]
itervp_Unet_diff = np.load(os.path.join(path2,"inversion-vp-Unet-3x128/iter_vp.npz"))["data"][:MAX_ITER]

# %%
plt.rcParams['svg.fonttype'] = 'none'
# import matplotlib as mpl
# mpl.rcParams['svg.hashsalt'] = None
# mpl.rcParams['svg.fonttype'] = 'none'
# mpl.rcParams['path.simplify'] = True
# mpl.rcParams['path.simplify_threshold'] = 0.01

fig,axs = plt.subplots(4,2,figsize=(13,10))
im = plot_vel_single_for_all(fig,axs[0][0],true_v          ,title=r"True Model")
plot_vel_single_for_all(fig,axs[0][1],itervp_baseline[-1]  ,title=r"Traditional FWI"        ,MSE="(b) MAPE:{:.2f}".format(MAPE(true_v,itervp_baseline[-1])))
plot_vel_single_for_all(fig,axs[1][0],itervp_Unet[-1]      ,title=r"Unet-$v_p$"             ,MSE="(c) MAPE:{:.2f}".format(MAPE(true_v,itervp_Unet[-1])))
plot_vel_single_for_all(fig,axs[1][1],itervp_Unet_diff[-1] ,title=r"Unet-$\Delta v_p$"      ,MSE="(d) MAPE:{:.2f}".format(MAPE(true_v,itervp_Unet_diff[-1])))
plot_vel_single_for_all(fig,axs[2][0],itervp_MLP[-1]       ,title=r"MLP-$v_p$"              ,MSE="(e) MAPE:{:.2f}".format(MAPE(true_v,itervp_MLP[-1])))
plot_vel_single_for_all(fig,axs[2][1],itervp_MLP_diff[-1]  ,title=r"MLP-$\Delta v_p$"       ,MSE="(f) MAPE:{:.2f}".format(MAPE(true_v,itervp_MLP_diff[-1])))
plot_vel_single_for_all(fig,axs[3][0],itervp_CNN[-1]       ,title=r"CNN-$v_p$"              ,MSE="(g) MAPE:{:.2f}".format(MAPE(true_v,itervp_CNN[-1])))
plot_vel_single_for_all(fig,axs[3][1],itervp_CNN_diff[-1]  ,title=r"CNN-$\Delta v_p$"       ,MSE="(h) MAPE:{:.2f}".format(MAPE(true_v,itervp_CNN_diff[-1])))

axs[0][0].scatter(rcv_x[1::2],rcv_z[1::2]+0.05,c="w",marker="v",s=10)
axs[0][0].scatter(src_x[1::2],src_z[1::2]+0.05,c="r",marker="*",s=60)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)

axs[1][0].set_ylabel("Depth (km)",fontsize=15)
axs[2][0].set_ylabel("Depth (km)",fontsize=15)
axs[3][0].set_ylabel("Depth (km)",fontsize=15)

axs[0][0].set_xticks([])
axs[0][1].set_xticks([])
axs[0][1].set_yticks([])

axs[1][0].set_xticks([])
axs[1][1].set_xticks([])
axs[1][1].set_yticks([])

axs[2][0].set_xticks([])
axs[2][1].set_xticks([])
axs[2][1].set_yticks([])

axs[3][1].set_yticks([])

from matplotlib.ticker import MaxNLocator
axs[0][0].yaxis.set_major_locator(MaxNLocator(5))
axs[1][0].yaxis.set_major_locator(MaxNLocator(5))
axs[2][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].xaxis.set_major_locator(MaxNLocator(8))
axs[3][1].xaxis.set_major_locator(MaxNLocator(8))

axs[3][0].set_xlabel("Distance (km)", fontsize=15)
axs[3][1].set_xlabel("Distance (km)", fontsize=15)

plt.subplots_adjust(hspace=0.2,wspace=0.03)

cbar = fig.colorbar(im, ax=axs,orientation='vertical',pad = 0.02,shrink=0.6)
cbar.ax.set_title("(m/s)",fontsize=15,loc='center')
cbar.ax.tick_params(labelsize=15)

axs[0][0].text(0.03, 0.82, "(a)", transform=axs[0][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='w')
# axs[0][1].text(0.01, 0.05, "(b)", transform=axs[0][1].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='k')
# axs[1][0].text(0.01, 0.05, "(c)", transform=axs[1][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='k')
# axs[1][1].text(0.01, 0.05, "(d)", transform=axs[1][1].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='k')
# axs[2][0].text(0.01, 0.05, "(e)", transform=axs[2][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='k')
# axs[2][1].text(0.01, 0.05, "(f)", transform=axs[2][1].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='k')
# axs[3][0].text(0.01, 0.05, "(g)", transform=axs[3][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='k')
# axs[3][1].text(0.01, 0.05, "(h)", transform=axs[3][1].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='k')

# plt.savefig("./Figures/Figure4_Architecture_and_Strategy_Marmousi2_model.png",bbox_inches='tight',dpi=300)
plt.savefig("./Figures_SVG/Figure4_Architecture_and_Strategy_Marmousi2_model.svg",bbox_inches='tight',format="svg")
# plt.savefig("./Figures_PDF/Figure4_Architecture_and_Strategy_Marmousi2_model.pdf",bbox_inches='tight',format="pdf",dpi=300)
plt.show()
