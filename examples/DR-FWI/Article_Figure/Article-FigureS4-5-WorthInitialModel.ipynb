# %%
import numpy as np
import matplotlib.pyplot as plt
import os

from ADFWI.utils import get_smooth_marmousi_model, load_marmousi_model, resample_marmousi_model
from ADFWI.utils.assessment_metric import MAPE, MSE, SNR, SSIM

base_path = "/home/bingxing2/ailab/scxlab0055/project/04_Inversion/ADFWI-github/examples/DR-FWI/Inductive_bias/initial_model/Marmousi2-nowater-SmoothInitModel/data-shot=40_smooth=8"

ox, oz  = 0, 0        
nz, nx  = 76, 200      
dx, dz  = 40, 40         
nt, dt  = 1600, 0.003     
nabc    = 30                 
x       = np.arange(nx)*dx/1000
z       = np.arange(nz)*dz/1000
x_mesh,z_mesh = np.meshgrid(x,z)
src_z = np.array([1  for i in range(2,nx-1,5)])*dz/1000
src_x = np.array([i  for i in range(2,nx-1,5)])*dx/1000
rcv_z = np.array([1  for i in range(0,nx,1)])*dz/1000
rcv_x = np.array([j  for j in range(0,nx,1)])*dz/1000

# Load the Marmousi model dataset from the specified directory.
marmousi_model = load_marmousi_model(in_dir="../../datasets/marmousi2_source")

# Create coordinate arrays for x and z based on the grid size.
x = np.linspace(5000, 5000 + dx * nx, nx)
z = np.linspace(500, 500+dz * nz, nz)
true_model   = resample_marmousi_model(x, z, marmousi_model)
smooth_model = get_smooth_marmousi_model(true_model, gaussian_kernel=8,mask_extra_detph=0,rcv_depth=0)

# Initialize primary wave velocity (vp) and density (rho) for the model.
init_v  = smooth_model['vp'].T   # Transpose to match dimensions
init_rho = smooth_model['rho'].T  # Calculate density based on vp

# Extract true model properties for comparison.
true_v  = true_model['vp'].T   # Transpose for consistency
true_rho = true_model['rho'].T  # Calculate true density

vmin = true_v.min();vmax = true_v.max()

# %% [markdown]
# ## CNN/MLP/Unet - v

# %%
itervp_baseline      = np.load(os.path.join(base_path,"inversion-vp-baseline/iter_vp.npz"))["data"]
iterloss_baseline    = np.load(os.path.join(base_path,"inversion-vp-baseline/iter_loss.npz"))["data"]

# %%
# cnn-v
itervp_CNN_v_1x64       = np.load(os.path.join(base_path,"inversion-vp-CNN-1x64/iter_vp.npz"))["data"]
itervp_CNN_v_1x128       = np.load(os.path.join(base_path,"inversion-vp-CNN-1x128/iter_vp.npz"))["data"]
itervp_CNN_v_1x256       = np.load(os.path.join(base_path,"inversion-vp-CNN-1x256/iter_vp.npz"))["data"]
itervp_CNN_v_1x512       = np.load(os.path.join(base_path,"inversion-vp-CNN-1x512/iter_vp.npz"))["data"]
itervp_CNN_v_2x64       = np.load(os.path.join(base_path,"inversion-vp-CNN-2x64/iter_vp.npz"))["data"]
itervp_CNN_v_2x128      = np.load(os.path.join(base_path,"inversion-vp-CNN-2x128/iter_vp.npz"))["data"]
itervp_CNN_v_2x256      = np.load(os.path.join(base_path,"inversion-vp-CNN-2x256/iter_vp.npz"))["data"]
itervp_CNN_v_2x512      = np.load(os.path.join(base_path,"inversion-vp-CNN-2x512/iter_vp.npz"))["data"]
itervp_CNN_v_3x64       = np.load(os.path.join(base_path,"inversion-vp-CNN-3x64/iter_vp.npz"))["data"]
itervp_CNN_v_3x128      = np.load(os.path.join(base_path,"inversion-vp-CNN-3x128/iter_vp.npz"))["data"]
itervp_CNN_v_3x256      = np.load(os.path.join(base_path,"inversion-vp-CNN-3x256/iter_vp.npz"))["data"]
itervp_CNN_v_3x512      = np.load(os.path.join(base_path,"inversion-vp-CNN-3x512/iter_vp.npz"))["data"]
itervp_CNN_v_4x64       = np.load(os.path.join(base_path,"inversion-vp-CNN-4x64/iter_vp.npz"))["data"]
itervp_CNN_v_4x128      = np.load(os.path.join(base_path,"inversion-vp-CNN-4x128/iter_vp.npz"))["data"]
itervp_CNN_v_4x256      = np.load(os.path.join(base_path,"inversion-vp-CNN-4x256/iter_vp.npz"))["data"]
itervp_CNN_v_4x512      = np.load(os.path.join(base_path,"inversion-vp-CNN-4x512/iter_vp.npz"))["data"]

iterloss_CNN_v_1x64     = np.load(os.path.join(base_path,"inversion-vp-CNN-1x64/iter_loss.npz"))["data"]
iterloss_CNN_v_1x128    = np.load(os.path.join(base_path,"inversion-vp-CNN-1x128/iter_loss.npz"))["data"]
iterloss_CNN_v_1x256    = np.load(os.path.join(base_path,"inversion-vp-CNN-1x256/iter_loss.npz"))["data"]
iterloss_CNN_v_1x512    = np.load(os.path.join(base_path,"inversion-vp-CNN-1x512/iter_loss.npz"))["data"]
iterloss_CNN_v_2x64     = np.load(os.path.join(base_path,"inversion-vp-CNN-2x64/iter_loss.npz"))["data"]
iterloss_CNN_v_2x128    = np.load(os.path.join(base_path,"inversion-vp-CNN-2x128/iter_loss.npz"))["data"]
iterloss_CNN_v_2x256    = np.load(os.path.join(base_path,"inversion-vp-CNN-2x256/iter_loss.npz"))["data"]
iterloss_CNN_v_2x512    = np.load(os.path.join(base_path,"inversion-vp-CNN-2x512/iter_loss.npz"))["data"]
iterloss_CNN_v_3x64     = np.load(os.path.join(base_path,"inversion-vp-CNN-3x64/iter_loss.npz"))["data"]
iterloss_CNN_v_3x128    = np.load(os.path.join(base_path,"inversion-vp-CNN-3x128/iter_loss.npz"))["data"]
iterloss_CNN_v_3x256    = np.load(os.path.join(base_path,"inversion-vp-CNN-3x256/iter_loss.npz"))["data"]
iterloss_CNN_v_3x512    = np.load(os.path.join(base_path,"inversion-vp-CNN-3x512/iter_loss.npz"))["data"]
iterloss_CNN_v_4x64     = np.load(os.path.join(base_path,"inversion-vp-CNN-4x64/iter_loss.npz"))["data"]
iterloss_CNN_v_4x128    = np.load(os.path.join(base_path,"inversion-vp-CNN-4x128/iter_loss.npz"))["data"]
iterloss_CNN_v_4x256    = np.load(os.path.join(base_path,"inversion-vp-CNN-4x256/iter_loss.npz"))["data"]
iterloss_CNN_v_4x512    = np.load(os.path.join(base_path,"inversion-vp-CNN-4x512/iter_loss.npz"))["data"]

# %%
# MLP-v
itervp_MLP_v_1x100      = np.load(os.path.join(base_path,"inversion-vp-MLP-1x100/iter_vp.npz"))["data"]
itervp_MLP_v_1x1000     = np.load(os.path.join(base_path,"inversion-vp-MLP-1x1000/iter_vp.npz"))["data"]
itervp_MLP_v_1x2000     = np.load(os.path.join(base_path,"inversion-vp-MLP-1x2000/iter_vp.npz"))["data"]
itervp_MLP_v_1x3000     = np.load(os.path.join(base_path,"inversion-vp-MLP-1x3000/iter_vp.npz"))["data"]
itervp_MLP_v_2x100      = np.load(os.path.join(base_path,"inversion-vp-MLP-2x100/iter_vp.npz"))["data"]
itervp_MLP_v_2x1000     = np.load(os.path.join(base_path,"inversion-vp-MLP-2x1000/iter_vp.npz"))["data"]
itervp_MLP_v_2x2000     = np.load(os.path.join(base_path,"inversion-vp-MLP-2x2000/iter_vp.npz"))["data"]
itervp_MLP_v_2x3000     = np.load(os.path.join(base_path,"inversion-vp-MLP-2x3000/iter_vp.npz"))["data"]

iterloss_MLP_v_1x100    = np.load(os.path.join(base_path,"inversion-vp-MLP-1x100/iter_loss.npz"))["data"]
iterloss_MLP_v_1x1000   = np.load(os.path.join(base_path,"inversion-vp-MLP-1x1000/iter_loss.npz"))["data"]
iterloss_MLP_v_1x2000   = np.load(os.path.join(base_path,"inversion-vp-MLP-1x2000/iter_loss.npz"))["data"]
iterloss_MLP_v_1x3000   = np.load(os.path.join(base_path,"inversion-vp-MLP-1x3000/iter_loss.npz"))["data"]
iterloss_MLP_v_2x100    = np.load(os.path.join(base_path,"inversion-vp-MLP-2x100/iter_loss.npz"))["data"]
iterloss_MLP_v_2x1000   = np.load(os.path.join(base_path,"inversion-vp-MLP-2x1000/iter_loss.npz"))["data"]
iterloss_MLP_v_2x2000   = np.load(os.path.join(base_path,"inversion-vp-MLP-2x2000/iter_loss.npz"))["data"]
iterloss_MLP_v_2x3000   = np.load(os.path.join(base_path,"inversion-vp-MLP-2x3000/iter_loss.npz"))["data"]

# %%
# unt-v
itervp_Unet_v_1x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x64/iter_vp.npz"))["data"]
itervp_Unet_v_1x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x128/iter_vp.npz"))["data"]
itervp_Unet_v_1x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x256/iter_vp.npz"))["data"]
itervp_Unet_v_1x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x512/iter_vp.npz"))["data"]
itervp_Unet_v_2x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x64/iter_vp.npz"))["data"]
itervp_Unet_v_2x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x128/iter_vp.npz"))["data"]
itervp_Unet_v_2x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x256/iter_vp.npz"))["data"]
itervp_Unet_v_2x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x512/iter_vp.npz"))["data"]
itervp_Unet_v_3x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x64/iter_vp.npz"))["data"]
itervp_Unet_v_3x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x128/iter_vp.npz"))["data"]
itervp_Unet_v_3x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x256/iter_vp.npz"))["data"]
itervp_Unet_v_3x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x512/iter_vp.npz"))["data"]
itervp_Unet_v_4x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x64/iter_vp.npz"))["data"]
itervp_Unet_v_4x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x128/iter_vp.npz"))["data"]
itervp_Unet_v_4x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x256/iter_vp.npz"))["data"]
# itervp_Unet_v_4x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x512/iter_vp.npz"))["data"]

iterloss_Unet_v_1x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x64/iter_loss.npz"))["data"]
iterloss_Unet_v_1x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x128/iter_loss.npz"))["data"]
iterloss_Unet_v_1x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x256/iter_loss.npz"))["data"]
iterloss_Unet_v_1x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-1x512/iter_loss.npz"))["data"]
iterloss_Unet_v_2x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x64/iter_loss.npz"))["data"]
iterloss_Unet_v_2x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x128/iter_loss.npz"))["data"]
iterloss_Unet_v_2x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x256/iter_loss.npz"))["data"]
iterloss_Unet_v_2x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-2x512/iter_loss.npz"))["data"]
iterloss_Unet_v_3x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x64/iter_loss.npz"))["data"]
iterloss_Unet_v_3x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x128/iter_loss.npz"))["data"]
iterloss_Unet_v_3x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x256/iter_loss.npz"))["data"]
iterloss_Unet_v_3x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-3x512/iter_loss.npz"))["data"]
iterloss_Unet_v_4x64      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x64/iter_loss.npz"))["data"]
iterloss_Unet_v_4x128      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x128/iter_loss.npz"))["data"]
iterloss_Unet_v_4x256      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x256/iter_loss.npz"))["data"]
# iterloss_Unet_v_4x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x512/iter_loss.npz"))["data"]

# %% [markdown]
# ### Loss comparason - v

# %%
MAX_ITER = 300

# %%
dloss_baseline = iterloss_baseline[:MAX_ITER]

dloss_cnn_v_all = np.array([
    iterloss_CNN_v_1x64[:MAX_ITER],iterloss_CNN_v_1x128[:MAX_ITER],iterloss_CNN_v_1x256[:MAX_ITER],iterloss_CNN_v_1x512[:MAX_ITER],
    iterloss_CNN_v_2x64[:MAX_ITER],iterloss_CNN_v_2x128[:MAX_ITER],iterloss_CNN_v_2x256[:MAX_ITER],iterloss_CNN_v_2x512[:MAX_ITER],
    iterloss_CNN_v_3x64[:MAX_ITER],iterloss_CNN_v_3x128[:MAX_ITER],iterloss_CNN_v_3x256[:MAX_ITER],iterloss_CNN_v_3x512[:MAX_ITER],
    iterloss_CNN_v_4x64[:MAX_ITER],iterloss_CNN_v_4x128[:MAX_ITER],iterloss_CNN_v_4x256[:MAX_ITER],iterloss_CNN_v_4x512[:MAX_ITER],
])

dloss_mlp_v_all = np.array([
    iterloss_MLP_v_1x100[:MAX_ITER],iterloss_MLP_v_1x1000[:MAX_ITER],iterloss_MLP_v_1x2000[:MAX_ITER],iterloss_MLP_v_1x3000[:MAX_ITER],
    iterloss_MLP_v_2x100[:MAX_ITER],iterloss_MLP_v_2x1000[:MAX_ITER],iterloss_MLP_v_2x2000[:MAX_ITER],iterloss_MLP_v_2x3000[:MAX_ITER],
])

dloss_unet_v_all = np.array([
    iterloss_Unet_v_1x64[:MAX_ITER],iterloss_Unet_v_1x128[:MAX_ITER],iterloss_Unet_v_1x256[:MAX_ITER],iterloss_Unet_v_1x512[:MAX_ITER],
    iterloss_Unet_v_2x64[:MAX_ITER],iterloss_Unet_v_2x128[:MAX_ITER],iterloss_Unet_v_2x256[:MAX_ITER],iterloss_Unet_v_2x512[:MAX_ITER],   
    iterloss_Unet_v_3x64[:MAX_ITER],iterloss_Unet_v_3x128[:MAX_ITER],iterloss_Unet_v_3x256[:MAX_ITER],iterloss_Unet_v_3x512[:MAX_ITER],   
    iterloss_Unet_v_4x64[:MAX_ITER],iterloss_Unet_v_4x128[:MAX_ITER],iterloss_Unet_v_4x256[:MAX_ITER],   
])

plt.figure()
plt.axhline(y=dloss_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(dloss_cnn_v_all.min(axis=1))),dloss_cnn_v_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(dloss_mlp_v_all.min(axis=1))),dloss_mlp_v_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(dloss_unet_v_all.min(axis=1))),dloss_unet_v_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.show()

# %%
mloss_mape_baseline    = MAPE(true_v,itervp_baseline[:MAX_ITER])

mloss_mape_CNN_v_1x64  = MAPE(true_v,itervp_CNN_v_1x64[:MAX_ITER])
mloss_mape_CNN_v_1x128 = MAPE(true_v,itervp_CNN_v_1x128[:MAX_ITER])
mloss_mape_CNN_v_1x256 = MAPE(true_v,itervp_CNN_v_1x256[:MAX_ITER])
mloss_mape_CNN_v_1x512 = MAPE(true_v,itervp_CNN_v_1x512[:MAX_ITER])
mloss_mape_CNN_v_2x64  = MAPE(true_v,itervp_CNN_v_2x64[:MAX_ITER])
mloss_mape_CNN_v_2x128 = MAPE(true_v,itervp_CNN_v_2x128[:MAX_ITER])
mloss_mape_CNN_v_2x256 = MAPE(true_v,itervp_CNN_v_2x256[:MAX_ITER])
mloss_mape_CNN_v_2x512 = MAPE(true_v,itervp_CNN_v_2x512[:MAX_ITER])
mloss_mape_CNN_v_3x64  = MAPE(true_v,itervp_CNN_v_3x64[:MAX_ITER])
mloss_mape_CNN_v_3x128 = MAPE(true_v,itervp_CNN_v_3x128[:MAX_ITER])
mloss_mape_CNN_v_3x256 = MAPE(true_v,itervp_CNN_v_3x256[:MAX_ITER])
mloss_mape_CNN_v_3x512 = MAPE(true_v,itervp_CNN_v_3x512[:MAX_ITER])
mloss_mape_CNN_v_4x64  = MAPE(true_v,itervp_CNN_v_4x64[:MAX_ITER])
mloss_mape_CNN_v_4x128 = MAPE(true_v,itervp_CNN_v_4x128[:MAX_ITER])
mloss_mape_CNN_v_4x256 = MAPE(true_v,itervp_CNN_v_4x256[:MAX_ITER])
mloss_mape_CNN_v_4x512 = MAPE(true_v,itervp_CNN_v_4x512[:MAX_ITER])

mloss_mape_MLP_v_1x100  = MAPE(true_v,itervp_MLP_v_1x100[:MAX_ITER])
mloss_mape_MLP_v_1x1000 = MAPE(true_v,itervp_MLP_v_1x1000[:MAX_ITER])
mloss_mape_MLP_v_1x2000 = MAPE(true_v,itervp_MLP_v_1x2000[:MAX_ITER])
mloss_mape_MLP_v_1x3000 = MAPE(true_v,itervp_MLP_v_1x3000[:MAX_ITER])
mloss_mape_MLP_v_2x100  = MAPE(true_v,itervp_MLP_v_2x100[:MAX_ITER])
mloss_mape_MLP_v_2x1000 = MAPE(true_v,itervp_MLP_v_2x1000[:MAX_ITER])
mloss_mape_MLP_v_2x2000 = MAPE(true_v,itervp_MLP_v_2x2000[:MAX_ITER])
mloss_mape_MLP_v_2x3000 = MAPE(true_v,itervp_MLP_v_2x3000[:MAX_ITER])

mloss_mape_Unet_v_1x64  = MAPE(true_v,itervp_Unet_v_1x64[:MAX_ITER])
mloss_mape_Unet_v_1x128 = MAPE(true_v,itervp_Unet_v_1x128[:MAX_ITER])
mloss_mape_Unet_v_1x256 = MAPE(true_v,itervp_Unet_v_1x256[:MAX_ITER])
mloss_mape_Unet_v_1x512 = MAPE(true_v,itervp_Unet_v_1x512[:MAX_ITER])
mloss_mape_Unet_v_2x64  = MAPE(true_v,itervp_Unet_v_2x64[:MAX_ITER])
mloss_mape_Unet_v_2x128 = MAPE(true_v,itervp_Unet_v_2x128[:MAX_ITER])
mloss_mape_Unet_v_2x256 = MAPE(true_v,itervp_Unet_v_2x256[:MAX_ITER])
mloss_mape_Unet_v_2x512 = MAPE(true_v,itervp_Unet_v_2x512[:MAX_ITER])
mloss_mape_Unet_v_3x64  = MAPE(true_v,itervp_Unet_v_3x64[:MAX_ITER])
mloss_mape_Unet_v_3x128 = MAPE(true_v,itervp_Unet_v_3x128[:MAX_ITER])
mloss_mape_Unet_v_3x256 = MAPE(true_v,itervp_Unet_v_3x256[:MAX_ITER])
mloss_mape_Unet_v_3x512 = MAPE(true_v,itervp_Unet_v_3x512[:MAX_ITER])
mloss_mape_Unet_v_4x64  = MAPE(true_v,itervp_Unet_v_4x64[:MAX_ITER])
mloss_mape_Unet_v_4x128 = MAPE(true_v,itervp_Unet_v_4x128[:MAX_ITER])
mloss_mape_Unet_v_4x256 = MAPE(true_v,itervp_Unet_v_4x256[:MAX_ITER])


mloss_mape_cnn_v_all = np.array([
    mloss_mape_CNN_v_1x64,mloss_mape_CNN_v_1x128,mloss_mape_CNN_v_1x256,mloss_mape_CNN_v_1x512,
    mloss_mape_CNN_v_2x64,mloss_mape_CNN_v_2x128,mloss_mape_CNN_v_2x256,mloss_mape_CNN_v_2x512,
    mloss_mape_CNN_v_3x64,mloss_mape_CNN_v_3x128,mloss_mape_CNN_v_3x256,mloss_mape_CNN_v_3x512,
    mloss_mape_CNN_v_4x64,mloss_mape_CNN_v_4x128,mloss_mape_CNN_v_4x256,mloss_mape_CNN_v_4x512,
])

mloss_mape_mlp_v_all = np.array([
    mloss_mape_MLP_v_1x100,mloss_mape_MLP_v_1x1000,mloss_mape_MLP_v_1x2000,mloss_mape_MLP_v_1x3000,
    mloss_mape_MLP_v_2x100,mloss_mape_MLP_v_2x1000,mloss_mape_MLP_v_2x2000,mloss_mape_MLP_v_2x3000,
])

mloss_mape_unet_v_all = np.array([
    mloss_mape_Unet_v_1x64,mloss_mape_Unet_v_1x128,mloss_mape_Unet_v_1x256,mloss_mape_Unet_v_1x512,
    mloss_mape_Unet_v_2x64,mloss_mape_Unet_v_2x128,mloss_mape_Unet_v_2x256,mloss_mape_Unet_v_2x512,   
    mloss_mape_Unet_v_3x64,mloss_mape_Unet_v_3x128,mloss_mape_Unet_v_3x256,mloss_mape_Unet_v_3x512,   
    mloss_mape_Unet_v_4x64,mloss_mape_Unet_v_4x128,mloss_mape_Unet_v_4x256,
])

plt.figure()
plt.axhline(y=mloss_mape_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(mloss_mape_cnn_v_all.min(axis=1))),mloss_mape_cnn_v_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(mloss_mape_mlp_v_all.min(axis=1))),mloss_mape_mlp_v_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(mloss_mape_unet_v_all.min(axis=1))),mloss_mape_unet_v_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.show()

# %%
WIN_SIZE = 3

mloss_ssim_baseline    = np.array(SSIM(true_v,itervp_baseline[:MAX_ITER],win_size=WIN_SIZE))

mloss_ssim_CNN_v_1x64  = np.array(SSIM(true_v,itervp_CNN_v_1x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_1x128 = np.array(SSIM(true_v,itervp_CNN_v_1x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_1x256 = np.array(SSIM(true_v,itervp_CNN_v_1x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_1x512 = np.array(SSIM(true_v,itervp_CNN_v_1x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_2x64  = np.array(SSIM(true_v,itervp_CNN_v_2x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_2x128 = np.array(SSIM(true_v,itervp_CNN_v_2x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_2x256 = np.array(SSIM(true_v,itervp_CNN_v_2x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_2x512 = np.array(SSIM(true_v,itervp_CNN_v_2x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_3x64  = np.array(SSIM(true_v,itervp_CNN_v_3x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_3x128 = np.array(SSIM(true_v,itervp_CNN_v_3x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_3x256 = np.array(SSIM(true_v,itervp_CNN_v_3x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_3x512 = np.array(SSIM(true_v,itervp_CNN_v_3x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_4x64  = np.array(SSIM(true_v,itervp_CNN_v_4x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_4x128 = np.array(SSIM(true_v,itervp_CNN_v_4x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_4x256 = np.array(SSIM(true_v,itervp_CNN_v_4x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_v_4x512 = np.array(SSIM(true_v,itervp_CNN_v_4x512[:MAX_ITER],win_size=WIN_SIZE))

mloss_ssim_MLP_v_1x100  = np.array(SSIM(true_v,itervp_MLP_v_1x100[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_v_1x1000 = np.array(SSIM(true_v,itervp_MLP_v_1x1000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_v_1x2000 = np.array(SSIM(true_v,itervp_MLP_v_1x2000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_v_1x3000 = np.array(SSIM(true_v,itervp_MLP_v_1x3000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_v_2x100  = np.array(SSIM(true_v,itervp_MLP_v_2x100[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_v_2x1000 = np.array(SSIM(true_v,itervp_MLP_v_2x1000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_v_2x2000 = np.array(SSIM(true_v,itervp_MLP_v_2x2000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_v_2x3000 = np.array(SSIM(true_v,itervp_MLP_v_2x3000[:MAX_ITER],win_size=WIN_SIZE))

mloss_ssim_Unet_v_1x64  = np.array(SSIM(true_v,itervp_Unet_v_1x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_1x128 = np.array(SSIM(true_v,itervp_Unet_v_1x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_1x256 = np.array(SSIM(true_v,itervp_Unet_v_1x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_1x512 = np.array(SSIM(true_v,itervp_Unet_v_1x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_2x64  = np.array(SSIM(true_v,itervp_Unet_v_2x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_2x128 = np.array(SSIM(true_v,itervp_Unet_v_2x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_2x256 = np.array(SSIM(true_v,itervp_Unet_v_2x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_2x512 = np.array(SSIM(true_v,itervp_Unet_v_2x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_3x64  = np.array(SSIM(true_v,itervp_Unet_v_3x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_3x128 = np.array(SSIM(true_v,itervp_Unet_v_3x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_3x256 = np.array(SSIM(true_v,itervp_Unet_v_3x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_3x512 = np.array(SSIM(true_v,itervp_Unet_v_3x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_4x64  = np.array(SSIM(true_v,itervp_Unet_v_4x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_4x128 = np.array(SSIM(true_v,itervp_Unet_v_4x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_v_4x256 = np.array(SSIM(true_v,itervp_Unet_v_4x256[:MAX_ITER],win_size=WIN_SIZE))


mloss_ssim_cnn_v_all = np.array([
    mloss_ssim_CNN_v_1x64,mloss_ssim_CNN_v_1x128,mloss_ssim_CNN_v_1x256,mloss_ssim_CNN_v_1x512,
    mloss_ssim_CNN_v_2x64,mloss_ssim_CNN_v_2x128,mloss_ssim_CNN_v_2x256,mloss_ssim_CNN_v_2x512,
    mloss_ssim_CNN_v_3x64,mloss_ssim_CNN_v_3x128,mloss_ssim_CNN_v_3x256,mloss_ssim_CNN_v_3x512,
    mloss_ssim_CNN_v_4x64,mloss_ssim_CNN_v_4x128,mloss_ssim_CNN_v_4x256,mloss_ssim_CNN_v_4x512,
])

mloss_ssim_mlp_v_all = np.array([
    mloss_ssim_MLP_v_1x100,mloss_ssim_MLP_v_1x1000,mloss_ssim_MLP_v_1x2000,mloss_ssim_MLP_v_1x3000,
    mloss_ssim_MLP_v_2x100,mloss_ssim_MLP_v_2x1000,mloss_ssim_MLP_v_2x2000,mloss_ssim_MLP_v_2x3000,
])

mloss_ssim_unet_v_all = np.array([
    mloss_ssim_Unet_v_1x64,mloss_ssim_Unet_v_1x128,mloss_ssim_Unet_v_1x256,mloss_ssim_Unet_v_1x512,
    mloss_ssim_Unet_v_2x64,mloss_ssim_Unet_v_2x128,mloss_ssim_Unet_v_2x256,mloss_ssim_Unet_v_2x512,   
    mloss_ssim_Unet_v_3x64,mloss_ssim_Unet_v_3x128,mloss_ssim_Unet_v_3x256,mloss_ssim_Unet_v_3x512,   
    mloss_ssim_Unet_v_4x64,mloss_ssim_Unet_v_4x128,mloss_ssim_Unet_v_4x256,
])

plt.figure()
plt.axhline(y=mloss_ssim_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(mloss_ssim_cnn_v_all.min(axis=1))),mloss_ssim_cnn_v_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(mloss_ssim_mlp_v_all.min(axis=1))),mloss_ssim_mlp_v_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(mloss_ssim_unet_v_all.min(axis=1))),mloss_ssim_unet_v_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.show()

# %%
mloss_snr_baseline    = np.array(SNR(true_v,itervp_baseline[:MAX_ITER]))

mloss_snr_CNN_v_1x64  = np.array(SNR(true_v,itervp_CNN_v_1x64[:MAX_ITER]))
mloss_snr_CNN_v_1x128 = np.array(SNR(true_v,itervp_CNN_v_1x128[:MAX_ITER]))
mloss_snr_CNN_v_1x256 = np.array(SNR(true_v,itervp_CNN_v_1x256[:MAX_ITER]))
mloss_snr_CNN_v_1x512 = np.array(SNR(true_v,itervp_CNN_v_1x512[:MAX_ITER]))
mloss_snr_CNN_v_2x64  = np.array(SNR(true_v,itervp_CNN_v_2x64[:MAX_ITER]))
mloss_snr_CNN_v_2x128 = np.array(SNR(true_v,itervp_CNN_v_2x128[:MAX_ITER]))
mloss_snr_CNN_v_2x256 = np.array(SNR(true_v,itervp_CNN_v_2x256[:MAX_ITER]))
mloss_snr_CNN_v_2x512 = np.array(SNR(true_v,itervp_CNN_v_2x512[:MAX_ITER]))
mloss_snr_CNN_v_3x64  = np.array(SNR(true_v,itervp_CNN_v_3x64[:MAX_ITER]))
mloss_snr_CNN_v_3x128 = np.array(SNR(true_v,itervp_CNN_v_3x128[:MAX_ITER]))
mloss_snr_CNN_v_3x256 = np.array(SNR(true_v,itervp_CNN_v_3x256[:MAX_ITER]))
mloss_snr_CNN_v_3x512 = np.array(SNR(true_v,itervp_CNN_v_3x512[:MAX_ITER]))
mloss_snr_CNN_v_4x64  = np.array(SNR(true_v,itervp_CNN_v_4x64[:MAX_ITER]))
mloss_snr_CNN_v_4x128 = np.array(SNR(true_v,itervp_CNN_v_4x128[:MAX_ITER]))
mloss_snr_CNN_v_4x256 = np.array(SNR(true_v,itervp_CNN_v_4x256[:MAX_ITER]))
mloss_snr_CNN_v_4x512 = np.array(SNR(true_v,itervp_CNN_v_4x512[:MAX_ITER]))

mloss_snr_MLP_v_1x100  = np.array(SNR(true_v,itervp_MLP_v_1x100[:MAX_ITER]))
mloss_snr_MLP_v_1x1000 = np.array(SNR(true_v,itervp_MLP_v_1x1000[:MAX_ITER]))
mloss_snr_MLP_v_1x2000 = np.array(SNR(true_v,itervp_MLP_v_1x2000[:MAX_ITER]))
mloss_snr_MLP_v_1x3000 = np.array(SNR(true_v,itervp_MLP_v_1x3000[:MAX_ITER]))
mloss_snr_MLP_v_2x100  = np.array(SNR(true_v,itervp_MLP_v_2x100[:MAX_ITER]))
mloss_snr_MLP_v_2x1000 = np.array(SNR(true_v,itervp_MLP_v_2x1000[:MAX_ITER]))
mloss_snr_MLP_v_2x2000 = np.array(SNR(true_v,itervp_MLP_v_2x2000[:MAX_ITER]))
mloss_snr_MLP_v_2x3000 = np.array(SNR(true_v,itervp_MLP_v_2x3000[:MAX_ITER]))

mloss_snr_Unet_v_1x64  = np.array(SNR(true_v,itervp_Unet_v_1x64[:MAX_ITER]))
mloss_snr_Unet_v_1x128 = np.array(SNR(true_v,itervp_Unet_v_1x128[:MAX_ITER]))
mloss_snr_Unet_v_1x256 = np.array(SNR(true_v,itervp_Unet_v_1x256[:MAX_ITER]))
mloss_snr_Unet_v_1x512 = np.array(SNR(true_v,itervp_Unet_v_1x512[:MAX_ITER]))
mloss_snr_Unet_v_2x64  = np.array(SNR(true_v,itervp_Unet_v_2x64[:MAX_ITER]))
mloss_snr_Unet_v_2x128 = np.array(SNR(true_v,itervp_Unet_v_2x128[:MAX_ITER]))
mloss_snr_Unet_v_2x256 = np.array(SNR(true_v,itervp_Unet_v_2x256[:MAX_ITER]))
mloss_snr_Unet_v_2x512 = np.array(SNR(true_v,itervp_Unet_v_2x512[:MAX_ITER]))
mloss_snr_Unet_v_3x64  = np.array(SNR(true_v,itervp_Unet_v_3x64[:MAX_ITER]))
mloss_snr_Unet_v_3x128 = np.array(SNR(true_v,itervp_Unet_v_3x128[:MAX_ITER]))
mloss_snr_Unet_v_3x256 = np.array(SNR(true_v,itervp_Unet_v_3x256[:MAX_ITER]))
mloss_snr_Unet_v_3x512 = np.array(SNR(true_v,itervp_Unet_v_3x512[:MAX_ITER]))
mloss_snr_Unet_v_4x64  = np.array(SNR(true_v,itervp_Unet_v_4x64[:MAX_ITER]))
mloss_snr_Unet_v_4x128 = np.array(SNR(true_v,itervp_Unet_v_4x128[:MAX_ITER]))
mloss_snr_Unet_v_4x256 = np.array(SNR(true_v,itervp_Unet_v_4x256[:MAX_ITER]))


mloss_snr_cnn_v_all = np.array([
    mloss_snr_CNN_v_1x64,mloss_snr_CNN_v_1x128,mloss_snr_CNN_v_1x256,mloss_snr_CNN_v_1x512,
    mloss_snr_CNN_v_2x64,mloss_snr_CNN_v_2x128,mloss_snr_CNN_v_2x256,mloss_snr_CNN_v_2x512,
    mloss_snr_CNN_v_3x64,mloss_snr_CNN_v_3x128,mloss_snr_CNN_v_3x256,mloss_snr_CNN_v_3x512,
    mloss_snr_CNN_v_4x64,mloss_snr_CNN_v_4x128,mloss_snr_CNN_v_4x256,mloss_snr_CNN_v_4x512,
])

mloss_snr_mlp_v_all = np.array([
    mloss_snr_MLP_v_1x100,mloss_snr_MLP_v_1x1000,mloss_snr_MLP_v_1x2000,mloss_snr_MLP_v_1x3000,
    mloss_snr_MLP_v_2x100,mloss_snr_MLP_v_2x1000,mloss_snr_MLP_v_2x2000,mloss_snr_MLP_v_2x3000,
])

mloss_snr_unet_v_all = np.array([
    mloss_snr_Unet_v_1x64,mloss_snr_Unet_v_1x128,mloss_snr_Unet_v_1x256,mloss_snr_Unet_v_1x512,
    mloss_snr_Unet_v_2x64,mloss_snr_Unet_v_2x128,mloss_snr_Unet_v_2x256,mloss_snr_Unet_v_2x512,   
    mloss_snr_Unet_v_3x64,mloss_snr_Unet_v_3x128,mloss_snr_Unet_v_3x256,mloss_snr_Unet_v_3x512,   
    mloss_snr_Unet_v_4x64,mloss_snr_Unet_v_4x128,mloss_snr_Unet_v_4x256,
])

plt.figure()
plt.axhline(y=mloss_snr_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(mloss_snr_cnn_v_all.min(axis=1))),mloss_snr_cnn_v_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(mloss_snr_mlp_v_all.min(axis=1))),mloss_snr_mlp_v_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(mloss_snr_unet_v_all.min(axis=1))),mloss_snr_unet_v_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.show()

# %%
select_model = 8

dloss_cnn_v_all_select  = np.sort(dloss_cnn_v_all,axis=0)
dloss_mlp_v_all_select  = np.sort(dloss_mlp_v_all,axis=0)
dloss_unet_v_all_select = np.sort(dloss_unet_v_all,axis=0)
dloss_cnn_v_all_select = dloss_cnn_v_all_select[:select_model,:]
dloss_mlp_v_all_select = dloss_mlp_v_all_select[:2,:]
dloss_unet_v_all_select = dloss_unet_v_all_select[:select_model,:]


mloss_mape_cnn_v_all_select  = np.sort(mloss_mape_cnn_v_all,axis=0)
mloss_mape_mlp_v_all_select  = np.sort(mloss_mape_mlp_v_all,axis=0)
mloss_mape_unet_v_all_select = np.sort(mloss_mape_unet_v_all,axis=0)
mloss_mape_cnn_v_all_select  = mloss_mape_cnn_v_all_select[:select_model,:]
mloss_mape_mlp_v_all_select  = mloss_mape_mlp_v_all_select[:2,:]
mloss_mape_unet_v_all_select = mloss_mape_unet_v_all_select[:select_model,:]

mloss_ssim_cnn_v_all_select  = np.sort(mloss_ssim_cnn_v_all,axis=0)
mloss_ssim_mlp_v_all_select  = np.sort(mloss_ssim_mlp_v_all,axis=0)
mloss_ssim_unet_v_all_select = np.sort(mloss_ssim_unet_v_all,axis=0)
mloss_ssim_cnn_v_all_select  = mloss_ssim_cnn_v_all_select[-select_model:,:]
mloss_ssim_mlp_v_all_select  = mloss_ssim_mlp_v_all_select[-2:,:]
mloss_ssim_unet_v_all_select = mloss_ssim_unet_v_all_select[-select_model:,:]

mloss_snr_cnn_v_all_select  = np.sort(mloss_snr_cnn_v_all,axis=0)
mloss_snr_mlp_v_all_select  = np.sort(mloss_snr_mlp_v_all,axis=0)
mloss_snr_unet_v_all_select = np.sort(mloss_snr_unet_v_all,axis=0)
mloss_snr_cnn_v_all_select  = mloss_snr_cnn_v_all_select[-select_model:,:]
mloss_snr_mlp_v_all_select  = mloss_snr_mlp_v_all_select[-2:,:]
mloss_snr_unet_v_all_select = mloss_snr_unet_v_all_select[-select_model:,:]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.lines import Line2D


palette = sns.color_palette("deep")
colors = {
    "Traditional FWI": "#4D4D4D",  # Dark gray
    "cnn_dv": palette[0],    # Blue for CNN-v
    "cnn_v": sns.dark_palette(palette[0], 2)[1],  # Darker blue for CNN-dv
    "mlp_dv": palette[1],    # Green for MLP-v
    "mlp_v": sns.dark_palette(palette[1], 2)[1],  # Darker green for MLP-dv
    "unet_dv": palette[2],   # Purple for Unet-v
    "unet_v": sns.dark_palette(palette[2], 2)[1]  # Darker purple for Unet-dv
}

# Set up the figure
fig = plt.figure(figsize=(12, 8))

#########################################################################################
# First subplot: Data Residual
ax1 = plt.subplot(221)

sparse_num = 2
xlist = np.arange(MAX_ITER)[::sparse_num]

baseline_losses = dloss_baseline[::sparse_num]
cnn_mean  = np.mean(dloss_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(dloss_cnn_v_all_select , axis=0)[::sparse_num]
mlp_mean  = np.mean(dloss_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(dloss_mlp_v_all_select , axis=0)[::sparse_num]
unet_mean = np.mean(dloss_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(dloss_unet_v_all_select, axis=0)[::sparse_num]

ax1.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax1.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax1.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax1.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)


ax1.set_ylabel('Global-Correlation Misfits', fontsize=14)
ax1.set_xticklabels([])
ax1.tick_params(axis="x", which="both", length=0)
ax1.grid(True, linestyle='--', alpha=0.6)

#######################################################
# Second subplot: Model Residual
ax2 = plt.subplot(222)

baseline_losses = mloss_mape_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_mape_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_mape_cnn_v_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_mape_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_mape_mlp_v_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_mape_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_mape_unet_v_all_select, axis=0)[::sparse_num]

ax2.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax2.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax2.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax2.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)


# Improve axis style
# ax2.set_ylabel('Mean Absolute Percentage Error', fontsize=12)
ax2.set_ylabel(r'MAPE ($\downarrow$)', fontsize=14)
# ax2.set_title("Model Residual", fontsize=12)
ax2.set_xticklabels([])  # Hide x-axis labels
ax2.tick_params(axis="x", which="both", length=0)
ax2.grid(True, linestyle='--', alpha=0.6)
# ax2.legend(loc='upper right', fontsize=10)


#######################################################
# Second subplot: Model Residual
ax3 = plt.subplot(223)
baseline_losses = mloss_snr_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_snr_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_snr_cnn_v_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_snr_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_snr_mlp_v_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_snr_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_snr_unet_v_all_select, axis=0)[::sparse_num]

ax3.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax3.plot(xlist, cnn_mean, linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax3.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax3.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)


# Improve axis style for second subplot
ax3.set_xlabel('Iterations', fontsize=15)
# ax3.set_ylabel('Signal-to-Noise Ratio', fontsize=12)
ax3.set_ylabel(r"SNR ($\uparrow$)", fontsize=14)
# ax3.set_title("Model Residual", fontsize=12)
ax3.grid(True, linestyle='--', alpha=0.6)

#######################################################
# Second subplot: Model Residual
ax4 = plt.subplot(224)
baseline_losses = mloss_ssim_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_ssim_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_ssim_cnn_v_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_ssim_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_ssim_mlp_v_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_ssim_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_ssim_unet_v_all_select, axis=0)[::sparse_num]

ax4.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax4.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax4.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax4.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# Improve axis style for second subplot
ax4.set_xlabel('Iterations', fontsize=15)
# ax4.set_ylabel('Structural Similarity Index Meansure', fontsize=12)
ax4.set_ylabel(r'SSIM ($\uparrow$)', fontsize=14)
# ax4.set_title("Model Residual", fontsize=12)
ax4.grid(True, linestyle='--', alpha=0.6)


# -------------------------------------------------------------
ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)
ax3.tick_params(labelsize=12)
ax4.tick_params(labelsize=12)

ax1.text(-0.17, 0.95, "(a)", transform=ax1.transAxes, fontsize=14, va='bottom', ha='left')
ax2.text(-0.12, 0.95, "(b)", transform=ax2.transAxes, fontsize=14, va='bottom', ha='left')
ax3.text(-0.11, 0.95, "(c)", transform=ax3.transAxes, fontsize=14, va='bottom', ha='left')
ax4.text(-0.13, 0.95, "(d)", transform=ax4.transAxes, fontsize=14, va='bottom', ha='left')

# Adjust layout
plt.tight_layout()


# legend
ordered_labels = [
    "Traditional FWI",
    "CNN-$v_p$",
    "MLP-$v_p$",
    "Unet-$v_p$",
]
placeholder = Line2D([0], [0], linestyle='none', label='', color='white')  # 不显示的图例项
handles, labels = ax2.get_legend_handles_labels()
label_to_handle = dict(zip(labels, handles))
label_to_handle[""] = placeholder
ordered_handles = [label_to_handle[label] for label in ordered_labels]
legend = plt.figlegend(ordered_handles, ordered_labels, loc='lower center', ncol=4, fontsize=15, frameon=False, bbox_to_anchor=(0.52, -0.12))

fig.canvas.draw()  # 确保 legend 被渲染
legend_box = legend.get_window_extent(fig.canvas.get_renderer()).transformed(fig.transFigure.inverted())

# 添加背景色框
from matplotlib.patches import FancyBboxPatch
background = FancyBboxPatch(
    (legend_box.x0 - 0.01, legend_box.y0),  # 左下角坐标
    legend_box.width + 0.01,                      # 宽度
    legend_box.height + 0.01,                     # 高度
    boxstyle="round,pad=0.01",                    # 可选的圆角样式
    transform=fig.transFigure,
    facecolor='#f8f8f8',
    edgecolor='none',
    zorder=0
)
fig.patches.append(background)

plt.show()

# %% [markdown]
# ## CNN/Unet/MLP-dv

# %%
# cnn-v
itervp_CNN_dv_1x64       = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x64/iter_vp.npz"))["data"]
itervp_CNN_dv_1x128      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x128/iter_vp.npz"))["data"]
itervp_CNN_dv_1x256      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x256/iter_vp.npz"))["data"]
itervp_CNN_dv_1x512      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x512/iter_vp.npz"))["data"]
itervp_CNN_dv_2x64       = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x64/iter_vp.npz"))["data"]
itervp_CNN_dv_2x128      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x128/iter_vp.npz"))["data"]
itervp_CNN_dv_2x256      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x256/iter_vp.npz"))["data"]
itervp_CNN_dv_2x512      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x512/iter_vp.npz"))["data"]
itervp_CNN_dv_3x64       = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x64/iter_vp.npz"))["data"]
itervp_CNN_dv_3x128      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x128/iter_vp.npz"))["data"]
itervp_CNN_dv_3x256      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x256/iter_vp.npz"))["data"]
itervp_CNN_dv_3x512      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x512/iter_vp.npz"))["data"]
itervp_CNN_dv_4x64       = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x64/iter_vp.npz"))["data"]
itervp_CNN_dv_4x128      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x128/iter_vp.npz"))["data"]
itervp_CNN_dv_4x256      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x256/iter_vp.npz"))["data"]
itervp_CNN_dv_4x512      = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x512/iter_vp.npz"))["data"]

iterloss_CNN_dv_1x64     = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x64/iter_loss.npz"))["data"]
iterloss_CNN_dv_1x128    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x128/iter_loss.npz"))["data"]
iterloss_CNN_dv_1x256    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x256/iter_loss.npz"))["data"]
iterloss_CNN_dv_1x512    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-1x512/iter_loss.npz"))["data"]
iterloss_CNN_dv_2x64     = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x64/iter_loss.npz"))["data"]
iterloss_CNN_dv_2x128    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x128/iter_loss.npz"))["data"]
iterloss_CNN_dv_2x256    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x256/iter_loss.npz"))["data"]
iterloss_CNN_dv_2x512    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-2x512/iter_loss.npz"))["data"]
iterloss_CNN_dv_3x64     = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x64/iter_loss.npz"))["data"]
iterloss_CNN_dv_3x128    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x128/iter_loss.npz"))["data"]
iterloss_CNN_dv_3x256    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x256/iter_loss.npz"))["data"]
iterloss_CNN_dv_3x512    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-3x512/iter_loss.npz"))["data"]
iterloss_CNN_dv_4x64     = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x64/iter_loss.npz"))["data"]
iterloss_CNN_dv_4x128    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x128/iter_loss.npz"))["data"]
iterloss_CNN_dv_4x256    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x256/iter_loss.npz"))["data"]
iterloss_CNN_dv_4x512    = np.load(os.path.join(base_path,"inversion-vp-dv-CNN-4x512/iter_loss.npz"))["data"]

# %%
# MLP-v
itervp_MLP_dv_1x100      = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x100/iter_vp.npz"))["data"]
itervp_MLP_dv_1x1000     = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x1000/iter_vp.npz"))["data"]
itervp_MLP_dv_1x2000     = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x2000/iter_vp.npz"))["data"]
itervp_MLP_dv_1x3000     = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x3000/iter_vp.npz"))["data"]
itervp_MLP_dv_2x100      = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x100/iter_vp.npz"))["data"]
itervp_MLP_dv_2x1000     = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x1000/iter_vp.npz"))["data"]
itervp_MLP_dv_2x2000     = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x2000/iter_vp.npz"))["data"]
itervp_MLP_dv_2x3000     = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x3000/iter_vp.npz"))["data"]

iterloss_MLP_dv_1x100    = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x100/iter_loss.npz"))["data"]
iterloss_MLP_dv_1x1000   = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x1000/iter_loss.npz"))["data"]
iterloss_MLP_dv_1x2000   = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x2000/iter_loss.npz"))["data"]
iterloss_MLP_dv_1x3000   = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-1x3000/iter_loss.npz"))["data"]
iterloss_MLP_dv_2x100    = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x100/iter_loss.npz"))["data"]
iterloss_MLP_dv_2x1000   = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x1000/iter_loss.npz"))["data"]
iterloss_MLP_dv_2x2000   = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x2000/iter_loss.npz"))["data"]
iterloss_MLP_dv_2x3000   = np.load(os.path.join(base_path,"inversion-vp-dv-MLP-2x3000/iter_loss.npz"))["data"]

# %%
# unt-v
itervp_Unet_dv_1x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x64/iter_vp.npz"))["data"]
itervp_Unet_dv_1x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x128/iter_vp.npz"))["data"]
itervp_Unet_dv_1x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x256/iter_vp.npz"))["data"]
itervp_Unet_dv_1x512     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x512/iter_vp.npz"))["data"]
itervp_Unet_dv_2x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x64/iter_vp.npz"))["data"]
itervp_Unet_dv_2x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x128/iter_vp.npz"))["data"]
itervp_Unet_dv_2x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x256/iter_vp.npz"))["data"]
itervp_Unet_dv_2x512     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x512/iter_vp.npz"))["data"]
itervp_Unet_dv_3x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x64/iter_vp.npz"))["data"]
itervp_Unet_dv_3x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x128/iter_vp.npz"))["data"]
itervp_Unet_dv_3x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x256/iter_vp.npz"))["data"]
itervp_Unet_dv_3x512     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x512/iter_vp.npz"))["data"]
itervp_Unet_dv_4x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-4x64/iter_vp.npz"))["data"]
itervp_Unet_dv_4x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-4x128/iter_vp.npz"))["data"]
itervp_Unet_dv_4x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-4x256/iter_vp.npz"))["data"]
# itervp_Unet_v_4x512     = np.load(os.path.join(base_path,"inversion-vp-Unet-4x512/iter_vp.npz"))["data"]

iterloss_Unet_dv_1x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x64/iter_loss.npz"))["data"]
iterloss_Unet_dv_1x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x128/iter_loss.npz"))["data"]
iterloss_Unet_dv_1x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x256/iter_loss.npz"))["data"]
iterloss_Unet_dv_1x512     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-1x512/iter_loss.npz"))["data"]
iterloss_Unet_dv_2x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x64/iter_loss.npz"))["data"]
iterloss_Unet_dv_2x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x128/iter_loss.npz"))["data"]
iterloss_Unet_dv_2x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x256/iter_loss.npz"))["data"]
iterloss_Unet_dv_2x512     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-2x512/iter_loss.npz"))["data"]
iterloss_Unet_dv_3x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x64/iter_loss.npz"))["data"]
iterloss_Unet_dv_3x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x128/iter_loss.npz"))["data"]
iterloss_Unet_dv_3x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x256/iter_loss.npz"))["data"]
iterloss_Unet_dv_3x512     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-3x512/iter_loss.npz"))["data"]
iterloss_Unet_dv_4x64      = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-4x64/iter_loss.npz"))["data"]
iterloss_Unet_dv_4x128     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-4x128/iter_loss.npz"))["data"]
iterloss_Unet_dv_4x256     = np.load(os.path.join(base_path,"inversion-vp-dv-Unet-4x256/iter_loss.npz"))["data"]
# iterloss_Unet_v_4x512      = np.load(os.path.join(base_path,"inversion-vp-Unet-4x512/iter_loss.npz"))["data"]

# %% [markdown]
# ### Loss comparason - dv

# %%
MAX_ITER = 300

# %%
dloss_cnn_dv_all = np.array([
    iterloss_CNN_dv_1x64[:MAX_ITER],iterloss_CNN_dv_1x128[:MAX_ITER],iterloss_CNN_dv_1x256[:MAX_ITER],iterloss_CNN_dv_1x512[:MAX_ITER],
    iterloss_CNN_dv_2x64[:MAX_ITER],iterloss_CNN_dv_2x128[:MAX_ITER],iterloss_CNN_dv_2x256[:MAX_ITER],iterloss_CNN_dv_2x512[:MAX_ITER],
    iterloss_CNN_dv_3x64[:MAX_ITER],iterloss_CNN_dv_3x128[:MAX_ITER],iterloss_CNN_dv_3x256[:MAX_ITER],iterloss_CNN_dv_3x512[:MAX_ITER],
    iterloss_CNN_dv_4x64[:MAX_ITER],iterloss_CNN_dv_4x128[:MAX_ITER],iterloss_CNN_dv_4x256[:MAX_ITER],iterloss_CNN_dv_4x512[:MAX_ITER],
])

dloss_mlp_dv_all = np.array([
    iterloss_MLP_dv_1x100[:MAX_ITER],iterloss_MLP_dv_1x1000[:MAX_ITER],iterloss_MLP_dv_1x2000[:MAX_ITER],iterloss_MLP_dv_1x3000[:MAX_ITER],
    iterloss_MLP_dv_2x100[:MAX_ITER],iterloss_MLP_dv_2x1000[:MAX_ITER],iterloss_MLP_dv_2x2000[:MAX_ITER],iterloss_MLP_dv_2x3000[:MAX_ITER],
])

dloss_unet_dv_all = np.array([
    iterloss_Unet_dv_1x64[:MAX_ITER],iterloss_Unet_dv_1x128[:MAX_ITER],iterloss_Unet_dv_1x256[:MAX_ITER],iterloss_Unet_dv_1x512[:MAX_ITER],
    iterloss_Unet_dv_2x64[:MAX_ITER],iterloss_Unet_dv_2x128[:MAX_ITER],iterloss_Unet_dv_2x256[:MAX_ITER],iterloss_Unet_dv_2x512[:MAX_ITER],   
    iterloss_Unet_dv_3x64[:MAX_ITER],iterloss_Unet_dv_3x128[:MAX_ITER],iterloss_Unet_dv_3x256[:MAX_ITER],iterloss_Unet_dv_3x512[:MAX_ITER],   
    iterloss_Unet_dv_4x64[:MAX_ITER],iterloss_Unet_dv_4x128[:MAX_ITER],iterloss_Unet_dv_4x256[:MAX_ITER],   
])

plt.figure()
plt.axhline(y=dloss_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(dloss_cnn_v_all.min(axis=1))),dloss_cnn_v_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(dloss_mlp_v_all.min(axis=1))),dloss_mlp_v_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(dloss_unet_v_all.min(axis=1))),dloss_unet_v_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.show()

# %%
mloss_mape_baseline    = MAPE(true_v,itervp_baseline[:MAX_ITER])

mloss_mape_CNN_dv_1x64  = MAPE(true_v,itervp_CNN_dv_1x64[:MAX_ITER])
mloss_mape_CNN_dv_1x128 = MAPE(true_v,itervp_CNN_dv_1x128[:MAX_ITER])
mloss_mape_CNN_dv_1x256 = MAPE(true_v,itervp_CNN_dv_1x256[:MAX_ITER])
mloss_mape_CNN_dv_1x512 = MAPE(true_v,itervp_CNN_dv_1x512[:MAX_ITER])
mloss_mape_CNN_dv_2x64  = MAPE(true_v,itervp_CNN_dv_2x64[:MAX_ITER])
mloss_mape_CNN_dv_2x128 = MAPE(true_v,itervp_CNN_dv_2x128[:MAX_ITER])
mloss_mape_CNN_dv_2x256 = MAPE(true_v,itervp_CNN_dv_2x256[:MAX_ITER])
mloss_mape_CNN_dv_2x512 = MAPE(true_v,itervp_CNN_dv_2x512[:MAX_ITER])
mloss_mape_CNN_dv_3x64  = MAPE(true_v,itervp_CNN_dv_3x64[:MAX_ITER])
mloss_mape_CNN_dv_3x128 = MAPE(true_v,itervp_CNN_dv_3x128[:MAX_ITER])
mloss_mape_CNN_dv_3x256 = MAPE(true_v,itervp_CNN_dv_3x256[:MAX_ITER])
mloss_mape_CNN_dv_3x512 = MAPE(true_v,itervp_CNN_dv_3x512[:MAX_ITER])
mloss_mape_CNN_dv_4x64  = MAPE(true_v,itervp_CNN_dv_4x64[:MAX_ITER])
mloss_mape_CNN_dv_4x128 = MAPE(true_v,itervp_CNN_dv_4x128[:MAX_ITER])
mloss_mape_CNN_dv_4x256 = MAPE(true_v,itervp_CNN_dv_4x256[:MAX_ITER])
mloss_mape_CNN_dv_4x512 = MAPE(true_v,itervp_CNN_dv_4x512[:MAX_ITER])

mloss_mape_MLP_dv_1x100  = MAPE(true_v,itervp_MLP_dv_1x100[:MAX_ITER])
mloss_mape_MLP_dv_1x1000 = MAPE(true_v,itervp_MLP_dv_1x1000[:MAX_ITER])
mloss_mape_MLP_dv_1x2000 = MAPE(true_v,itervp_MLP_dv_1x2000[:MAX_ITER])
mloss_mape_MLP_dv_1x3000 = MAPE(true_v,itervp_MLP_dv_1x3000[:MAX_ITER])
mloss_mape_MLP_dv_2x100  = MAPE(true_v,itervp_MLP_dv_2x100[:MAX_ITER])
mloss_mape_MLP_dv_2x1000 = MAPE(true_v,itervp_MLP_dv_2x1000[:MAX_ITER])
mloss_mape_MLP_dv_2x2000 = MAPE(true_v,itervp_MLP_dv_2x2000[:MAX_ITER])
mloss_mape_MLP_dv_2x3000 = MAPE(true_v,itervp_MLP_dv_2x3000[:MAX_ITER])

mloss_mape_Unet_dv_1x64  = MAPE(true_v,itervp_Unet_dv_1x64[:MAX_ITER])
mloss_mape_Unet_dv_1x128 = MAPE(true_v,itervp_Unet_dv_1x128[:MAX_ITER])
mloss_mape_Unet_dv_1x256 = MAPE(true_v,itervp_Unet_dv_1x256[:MAX_ITER])
mloss_mape_Unet_dv_1x512 = MAPE(true_v,itervp_Unet_dv_1x512[:MAX_ITER])
mloss_mape_Unet_dv_2x64  = MAPE(true_v,itervp_Unet_dv_2x64[:MAX_ITER])
mloss_mape_Unet_dv_2x128 = MAPE(true_v,itervp_Unet_dv_2x128[:MAX_ITER])
mloss_mape_Unet_dv_2x256 = MAPE(true_v,itervp_Unet_dv_2x256[:MAX_ITER])
mloss_mape_Unet_dv_2x512 = MAPE(true_v,itervp_Unet_dv_2x512[:MAX_ITER])
mloss_mape_Unet_dv_3x64  = MAPE(true_v,itervp_Unet_dv_3x64[:MAX_ITER])
mloss_mape_Unet_dv_3x128 = MAPE(true_v,itervp_Unet_dv_3x128[:MAX_ITER])
mloss_mape_Unet_dv_3x256 = MAPE(true_v,itervp_Unet_dv_3x256[:MAX_ITER])
mloss_mape_Unet_dv_3x512 = MAPE(true_v,itervp_Unet_dv_3x512[:MAX_ITER])
mloss_mape_Unet_dv_4x64  = MAPE(true_v,itervp_Unet_dv_4x64[:MAX_ITER])
mloss_mape_Unet_dv_4x128 = MAPE(true_v,itervp_Unet_dv_4x128[:MAX_ITER])
mloss_mape_Unet_dv_4x256 = MAPE(true_v,itervp_Unet_dv_4x256[:MAX_ITER])


mloss_mape_cnn_dv_all = np.array([
    mloss_mape_CNN_dv_1x64,mloss_mape_CNN_dv_1x128,mloss_mape_CNN_dv_1x256,mloss_mape_CNN_dv_1x512,
    mloss_mape_CNN_dv_2x64,mloss_mape_CNN_dv_2x128,mloss_mape_CNN_dv_2x256,mloss_mape_CNN_dv_2x512,
    mloss_mape_CNN_dv_3x64,mloss_mape_CNN_dv_3x128,mloss_mape_CNN_dv_3x256,mloss_mape_CNN_dv_3x512,
    mloss_mape_CNN_dv_4x64,mloss_mape_CNN_dv_4x128,mloss_mape_CNN_dv_4x256,
])

mloss_mape_mlp_dv_all = np.array([
    mloss_mape_MLP_dv_1x100,mloss_mape_MLP_dv_1x1000,mloss_mape_MLP_dv_1x2000,mloss_mape_MLP_dv_1x3000,
    mloss_mape_MLP_dv_2x100,mloss_mape_MLP_dv_2x1000,mloss_mape_MLP_dv_2x2000,mloss_mape_MLP_dv_2x3000,
])

mloss_mape_unet_dv_all = np.array([
    mloss_mape_Unet_dv_1x64,mloss_mape_Unet_dv_1x128,mloss_mape_Unet_dv_1x256,mloss_mape_Unet_dv_1x512,
    mloss_mape_Unet_dv_2x64,mloss_mape_Unet_dv_2x128,mloss_mape_Unet_dv_2x256,mloss_mape_Unet_dv_2x512,   
    mloss_mape_Unet_dv_3x64,mloss_mape_Unet_dv_3x128,mloss_mape_Unet_dv_3x256,mloss_mape_Unet_dv_3x512,   
    mloss_mape_Unet_dv_4x64,mloss_mape_Unet_dv_4x128,mloss_mape_Unet_dv_4x256,
])

plt.figure()
plt.axhline(y=mloss_mape_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(mloss_mape_cnn_dv_all.min(axis=1))),mloss_mape_cnn_dv_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(mloss_mape_mlp_dv_all.min(axis=1))),mloss_mape_mlp_dv_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(mloss_mape_unet_dv_all.min(axis=1))),mloss_mape_unet_dv_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.ylim(np.min(mloss_mape_cnn_dv_all.min(axis=1))-1,mloss_mape_baseline.min()+1)
plt.show()

# %%
WIN_SIZE = 3

mloss_ssim_baseline    = np.array(SSIM(true_v,itervp_baseline[:MAX_ITER],win_size=WIN_SIZE))

mloss_ssim_CNN_dv_1x64  = np.array(SSIM(true_v,itervp_CNN_dv_1x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_1x128 = np.array(SSIM(true_v,itervp_CNN_dv_1x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_1x256 = np.array(SSIM(true_v,itervp_CNN_dv_1x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_1x512 = np.array(SSIM(true_v,itervp_CNN_dv_1x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_2x64  = np.array(SSIM(true_v,itervp_CNN_dv_2x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_2x128 = np.array(SSIM(true_v,itervp_CNN_dv_2x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_2x256 = np.array(SSIM(true_v,itervp_CNN_dv_2x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_2x512 = np.array(SSIM(true_v,itervp_CNN_dv_2x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_3x64  = np.array(SSIM(true_v,itervp_CNN_dv_3x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_3x128 = np.array(SSIM(true_v,itervp_CNN_dv_3x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_3x256 = np.array(SSIM(true_v,itervp_CNN_dv_3x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_3x512 = np.array(SSIM(true_v,itervp_CNN_dv_3x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_4x64  = np.array(SSIM(true_v,itervp_CNN_dv_4x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_4x128 = np.array(SSIM(true_v,itervp_CNN_dv_4x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_4x256 = np.array(SSIM(true_v,itervp_CNN_dv_4x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_CNN_dv_4x512 = np.array(SSIM(true_v,itervp_CNN_dv_4x512[:MAX_ITER],win_size=WIN_SIZE))

mloss_ssim_MLP_dv_1x100  = np.array(SSIM(true_v,itervp_MLP_dv_1x100[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_dv_1x1000 = np.array(SSIM(true_v,itervp_MLP_dv_1x1000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_dv_1x2000 = np.array(SSIM(true_v,itervp_MLP_dv_1x2000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_dv_1x3000 = np.array(SSIM(true_v,itervp_MLP_dv_1x3000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_dv_2x100  = np.array(SSIM(true_v,itervp_MLP_dv_2x100[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_dv_2x1000 = np.array(SSIM(true_v,itervp_MLP_dv_2x1000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_dv_2x2000 = np.array(SSIM(true_v,itervp_MLP_dv_2x2000[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_MLP_dv_2x3000 = np.array(SSIM(true_v,itervp_MLP_dv_2x3000[:MAX_ITER],win_size=WIN_SIZE))

mloss_ssim_Unet_dv_1x64  = np.array(SSIM(true_v,itervp_Unet_dv_1x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_1x128 = np.array(SSIM(true_v,itervp_Unet_dv_1x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_1x256 = np.array(SSIM(true_v,itervp_Unet_dv_1x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_1x512 = np.array(SSIM(true_v,itervp_Unet_dv_1x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_2x64  = np.array(SSIM(true_v,itervp_Unet_dv_2x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_2x128 = np.array(SSIM(true_v,itervp_Unet_dv_2x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_2x256 = np.array(SSIM(true_v,itervp_Unet_dv_2x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_2x512 = np.array(SSIM(true_v,itervp_Unet_dv_2x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_3x64  = np.array(SSIM(true_v,itervp_Unet_dv_3x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_3x128 = np.array(SSIM(true_v,itervp_Unet_dv_3x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_3x256 = np.array(SSIM(true_v,itervp_Unet_dv_3x256[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_3x512 = np.array(SSIM(true_v,itervp_Unet_dv_3x512[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_4x64  = np.array(SSIM(true_v,itervp_Unet_dv_4x64[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_4x128 = np.array(SSIM(true_v,itervp_Unet_dv_4x128[:MAX_ITER],win_size=WIN_SIZE))
mloss_ssim_Unet_dv_4x256 = np.array(SSIM(true_v,itervp_Unet_dv_4x256[:MAX_ITER],win_size=WIN_SIZE))


mloss_ssim_cnn_dv_all = np.array([
    mloss_ssim_CNN_dv_1x64,mloss_ssim_CNN_dv_1x128,mloss_ssim_CNN_dv_1x256,mloss_ssim_CNN_dv_1x512,
    mloss_ssim_CNN_dv_2x64,mloss_ssim_CNN_dv_2x128,mloss_ssim_CNN_dv_2x256,mloss_ssim_CNN_dv_2x512,
    mloss_ssim_CNN_dv_3x64,mloss_ssim_CNN_dv_3x128,mloss_ssim_CNN_dv_3x256,mloss_ssim_CNN_dv_3x512,
    mloss_ssim_CNN_dv_4x64,mloss_ssim_CNN_dv_4x128,mloss_ssim_CNN_dv_4x256,mloss_ssim_CNN_dv_4x512,
])

mloss_ssim_mlp_dv_all = np.array([
    mloss_ssim_MLP_dv_1x100,mloss_ssim_MLP_dv_1x1000,mloss_ssim_MLP_dv_1x2000,mloss_ssim_MLP_dv_1x3000,
    mloss_ssim_MLP_dv_2x100,mloss_ssim_MLP_dv_2x1000,mloss_ssim_MLP_dv_2x2000,mloss_ssim_MLP_dv_2x3000,
])

mloss_ssim_unet_dv_all = np.array([
    mloss_ssim_Unet_dv_1x64,mloss_ssim_Unet_dv_1x128,mloss_ssim_Unet_dv_1x256,mloss_ssim_Unet_dv_1x512,
    mloss_ssim_Unet_dv_2x64,mloss_ssim_Unet_dv_2x128,mloss_ssim_Unet_dv_2x256,mloss_ssim_Unet_dv_2x512,   
    mloss_ssim_Unet_dv_3x64,mloss_ssim_Unet_dv_3x128,mloss_ssim_Unet_dv_3x256,mloss_ssim_Unet_dv_3x512,   
    mloss_ssim_Unet_dv_4x64,mloss_ssim_Unet_dv_4x128,mloss_ssim_Unet_dv_4x256,
])

plt.figure()
plt.axhline(y=mloss_ssim_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(mloss_ssim_cnn_dv_all.min(axis=1))),mloss_ssim_cnn_dv_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(mloss_ssim_mlp_dv_all.min(axis=1))),mloss_ssim_mlp_dv_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(mloss_ssim_unet_dv_all.min(axis=1))),mloss_ssim_unet_dv_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.show()

# %%
mloss_snr_baseline    = np.array(SNR(true_v,itervp_baseline[:MAX_ITER]))

mloss_snr_CNN_dv_1x64  = np.array(SNR(true_v,itervp_CNN_dv_1x64[:MAX_ITER]))
mloss_snr_CNN_dv_1x128 = np.array(SNR(true_v,itervp_CNN_dv_1x128[:MAX_ITER]))
mloss_snr_CNN_dv_1x256 = np.array(SNR(true_v,itervp_CNN_dv_1x256[:MAX_ITER]))
mloss_snr_CNN_dv_1x512 = np.array(SNR(true_v,itervp_CNN_dv_1x512[:MAX_ITER]))
mloss_snr_CNN_dv_2x64  = np.array(SNR(true_v,itervp_CNN_dv_2x64[:MAX_ITER]))
mloss_snr_CNN_dv_2x128 = np.array(SNR(true_v,itervp_CNN_dv_2x128[:MAX_ITER]))
mloss_snr_CNN_dv_2x256 = np.array(SNR(true_v,itervp_CNN_dv_2x256[:MAX_ITER]))
mloss_snr_CNN_dv_2x512 = np.array(SNR(true_v,itervp_CNN_dv_2x512[:MAX_ITER]))
mloss_snr_CNN_dv_3x64  = np.array(SNR(true_v,itervp_CNN_dv_3x64[:MAX_ITER]))
mloss_snr_CNN_dv_3x128 = np.array(SNR(true_v,itervp_CNN_dv_3x128[:MAX_ITER]))
mloss_snr_CNN_dv_3x256 = np.array(SNR(true_v,itervp_CNN_dv_3x256[:MAX_ITER]))
mloss_snr_CNN_dv_3x512 = np.array(SNR(true_v,itervp_CNN_dv_3x512[:MAX_ITER]))
mloss_snr_CNN_dv_4x64  = np.array(SNR(true_v,itervp_CNN_dv_4x64[:MAX_ITER]))
mloss_snr_CNN_dv_4x128 = np.array(SNR(true_v,itervp_CNN_dv_4x128[:MAX_ITER]))
mloss_snr_CNN_dv_4x256 = np.array(SNR(true_v,itervp_CNN_dv_4x256[:MAX_ITER]))
mloss_snr_CNN_dv_4x512 = np.array(SNR(true_v,itervp_CNN_dv_4x512[:MAX_ITER]))

mloss_snr_MLP_dv_1x100  = np.array(SNR(true_v,itervp_MLP_dv_1x100[:MAX_ITER]))
mloss_snr_MLP_dv_1x1000 = np.array(SNR(true_v,itervp_MLP_dv_1x1000[:MAX_ITER]))
mloss_snr_MLP_dv_1x2000 = np.array(SNR(true_v,itervp_MLP_dv_1x2000[:MAX_ITER]))
mloss_snr_MLP_dv_1x3000 = np.array(SNR(true_v,itervp_MLP_dv_1x3000[:MAX_ITER]))
mloss_snr_MLP_dv_2x100  = np.array(SNR(true_v,itervp_MLP_dv_2x100[:MAX_ITER]))
mloss_snr_MLP_dv_2x1000 = np.array(SNR(true_v,itervp_MLP_dv_2x1000[:MAX_ITER]))
mloss_snr_MLP_dv_2x2000 = np.array(SNR(true_v,itervp_MLP_dv_2x2000[:MAX_ITER]))
mloss_snr_MLP_dv_2x3000 = np.array(SNR(true_v,itervp_MLP_dv_2x3000[:MAX_ITER]))

mloss_snr_Unet_dv_1x64  = np.array(SNR(true_v,itervp_Unet_dv_1x64[:MAX_ITER]))
mloss_snr_Unet_dv_1x128 = np.array(SNR(true_v,itervp_Unet_dv_1x128[:MAX_ITER]))
mloss_snr_Unet_dv_1x256 = np.array(SNR(true_v,itervp_Unet_dv_1x256[:MAX_ITER]))
mloss_snr_Unet_dv_1x512 = np.array(SNR(true_v,itervp_Unet_dv_1x512[:MAX_ITER]))
mloss_snr_Unet_dv_2x64  = np.array(SNR(true_v,itervp_Unet_dv_2x64[:MAX_ITER]))
mloss_snr_Unet_dv_2x128 = np.array(SNR(true_v,itervp_Unet_dv_2x128[:MAX_ITER]))
mloss_snr_Unet_dv_2x256 = np.array(SNR(true_v,itervp_Unet_dv_2x256[:MAX_ITER]))
mloss_snr_Unet_dv_2x512 = np.array(SNR(true_v,itervp_Unet_dv_2x512[:MAX_ITER]))
mloss_snr_Unet_dv_3x64  = np.array(SNR(true_v,itervp_Unet_dv_3x64[:MAX_ITER]))
mloss_snr_Unet_dv_3x128 = np.array(SNR(true_v,itervp_Unet_dv_3x128[:MAX_ITER]))
mloss_snr_Unet_dv_3x256 = np.array(SNR(true_v,itervp_Unet_dv_3x256[:MAX_ITER]))
mloss_snr_Unet_dv_3x512 = np.array(SNR(true_v,itervp_Unet_dv_3x512[:MAX_ITER]))
mloss_snr_Unet_dv_4x64  = np.array(SNR(true_v,itervp_Unet_dv_4x64[:MAX_ITER]))
mloss_snr_Unet_dv_4x128 = np.array(SNR(true_v,itervp_Unet_dv_4x128[:MAX_ITER]))
mloss_snr_Unet_dv_4x256 = np.array(SNR(true_v,itervp_Unet_dv_4x256[:MAX_ITER]))


mloss_snr_cnn_dv_all = np.array([
    mloss_snr_CNN_dv_1x64,mloss_snr_CNN_dv_1x128,mloss_snr_CNN_dv_1x256,mloss_snr_CNN_dv_1x512,
    mloss_snr_CNN_dv_2x64,mloss_snr_CNN_dv_2x128,mloss_snr_CNN_dv_2x256,mloss_snr_CNN_dv_2x512,
    mloss_snr_CNN_dv_3x64,mloss_snr_CNN_dv_3x128,mloss_snr_CNN_dv_3x256,mloss_snr_CNN_dv_3x512,
    mloss_snr_CNN_dv_4x64,mloss_snr_CNN_dv_4x128,mloss_snr_CNN_dv_4x256,mloss_snr_CNN_dv_4x512,
])

mloss_snr_mlp_dv_all = np.array([
    mloss_snr_MLP_dv_1x100,mloss_snr_MLP_dv_1x1000,mloss_snr_MLP_dv_1x2000,mloss_snr_MLP_dv_1x3000,
    mloss_snr_MLP_dv_2x100,mloss_snr_MLP_dv_2x1000,mloss_snr_MLP_dv_2x2000,mloss_snr_MLP_dv_2x3000,
])

mloss_snr_unet_dv_all = np.array([
    mloss_snr_Unet_dv_1x64,mloss_snr_Unet_dv_1x128,mloss_snr_Unet_dv_1x256,mloss_snr_Unet_dv_1x512,
    mloss_snr_Unet_dv_2x64,mloss_snr_Unet_dv_2x128,mloss_snr_Unet_dv_2x256,mloss_snr_Unet_dv_2x512,   
    mloss_snr_Unet_dv_3x64,mloss_snr_Unet_dv_3x128,mloss_snr_Unet_dv_3x256,mloss_snr_Unet_dv_3x512,   
    mloss_snr_Unet_dv_4x64,mloss_snr_Unet_dv_4x128,mloss_snr_Unet_dv_4x256,
])

plt.figure()
plt.axhline(y=mloss_snr_baseline.min(),c="k",label="Baseline",linestyle="--")
plt.scatter(np.arange(len(mloss_snr_cnn_dv_all.min(axis=1))),mloss_snr_cnn_dv_all.min(axis=1),c="r",label="CNN")
plt.scatter(np.arange(len(mloss_snr_mlp_dv_all.min(axis=1))),mloss_snr_mlp_dv_all.min(axis=1),c="b",label="MLP")
plt.scatter(np.arange(len(mloss_snr_unet_dv_all.min(axis=1))),mloss_snr_unet_dv_all.min(axis=1),c="g",label="Unet")
plt.legend()
plt.show()

# %%
select_model = 8

dloss_cnn_dv_all_select       = np.sort(dloss_cnn_dv_all,axis=0)
dloss_mlp_dv_all_select       = np.sort(dloss_mlp_dv_all,axis=0)
dloss_unet_dv_all_select      = np.sort(dloss_unet_dv_all,axis=0)
dloss_cnn_dv_all_select       = dloss_cnn_dv_all_select[:select_model,:]
dloss_mlp_dv_all_select       = dloss_mlp_dv_all_select[:6,:]
dloss_unet_dv_all_select      = dloss_unet_dv_all_select[:select_model,:]


mloss_mape_cnn_dv_all_select  = np.sort(mloss_mape_cnn_dv_all,axis=0)
mloss_mape_mlp_dv_all_select  = np.sort(mloss_mape_mlp_dv_all,axis=0)
mloss_mape_unet_dv_all_select = np.sort(mloss_mape_unet_dv_all,axis=0)
mloss_mape_cnn_dv_all_select  = mloss_mape_cnn_dv_all_select[:select_model,:]
mloss_mape_mlp_dv_all_select  = mloss_mape_mlp_dv_all_select[:6,:]
mloss_mape_unet_dv_all_select = mloss_mape_unet_dv_all_select[:select_model,:]

mloss_ssim_cnn_dv_all_select  = np.sort(mloss_ssim_cnn_dv_all,axis=0)
mloss_ssim_mlp_dv_all_select  = np.sort(mloss_ssim_mlp_dv_all,axis=0)
mloss_ssim_unet_dv_all_select = np.sort(mloss_ssim_unet_dv_all,axis=0)
mloss_ssim_cnn_dv_all_select  = mloss_ssim_cnn_dv_all_select[-select_model:,:]
mloss_ssim_mlp_dv_all_select  = mloss_ssim_mlp_dv_all_select[-6:,:]
mloss_ssim_unet_dv_all_select = mloss_ssim_unet_dv_all_select[-select_model:,:]

mloss_snr_cnn_dv_all_select  = np.sort(mloss_snr_cnn_dv_all,axis=0)
mloss_snr_mlp_dv_all_select  = np.sort(mloss_snr_mlp_dv_all,axis=0)
mloss_snr_unet_dv_all_select = np.sort(mloss_snr_unet_dv_all,axis=0)
mloss_snr_cnn_dv_all_select  = mloss_snr_cnn_dv_all_select[-select_model:,:]
mloss_snr_mlp_dv_all_select  = mloss_snr_mlp_dv_all_select[-6:,:]
mloss_snr_unet_dv_all_select = mloss_snr_unet_dv_all_select[-select_model:,:]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.lines import Line2D


palette = sns.color_palette("deep")
colors = {
    "Traditional FWI": "#4D4D4D",  # Dark gray
    "cnn_dv": palette[0],    # Blue for CNN-v
    "cnn_v": sns.dark_palette(palette[0], 2)[1],  # Darker blue for CNN-dv
    "mlp_dv": palette[1],    # Green for MLP-v
    "mlp_v": sns.dark_palette(palette[1], 2)[1],  # Darker green for MLP-dv
    "unet_dv": palette[2],   # Purple for Unet-v
    "unet_v": sns.dark_palette(palette[2], 2)[1]  # Darker purple for Unet-dv
}

# Set up the figure
fig = plt.figure(figsize=(12, 8))

#########################################################################################
# First subplot: Data Residual
ax1 = plt.subplot(221)

sparse_num = 2
xlist = np.arange(MAX_ITER)[::sparse_num]

baseline_losses = dloss_baseline[::sparse_num]
cnn_mean  = np.mean(dloss_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(dloss_cnn_dv_all_select , axis=0)[::sparse_num]
mlp_mean  = np.mean(dloss_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(dloss_mlp_dv_all_select , axis=0)[::sparse_num]
unet_mean = np.mean(dloss_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(dloss_unet_dv_all_select, axis=0)[::sparse_num]

ax1.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax1.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax1.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax1.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)


ax1.set_ylabel('Global-Correlation Misfits', fontsize=14)
ax1.set_xticklabels([])
ax1.tick_params(axis="x", which="both", length=0)
ax1.grid(True, linestyle='--', alpha=0.6)



#######################################################
# Second subplot: Model Residual
ax2 = plt.subplot(222)

baseline_losses = mloss_mape_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_mape_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_mape_cnn_dv_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_mape_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_mape_mlp_dv_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_mape_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_mape_unet_dv_all_select, axis=0)[::sparse_num]

ax2.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax2.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax2.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax2.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)


# Improve axis style
# ax2.set_ylabel('Mean Absolute Percentage Error', fontsize=12)
ax2.set_ylabel(r'MAPE ($\downarrow$)', fontsize=14)
# ax2.set_title("Model Residual", fontsize=12)
ax2.set_xticklabels([])  # Hide x-axis labels
ax2.tick_params(axis="x", which="both", length=0)
ax2.grid(True, linestyle='--', alpha=0.6)
# ax2.legend(loc='upper right', fontsize=10)


#######################################################
# Second subplot: Model Residual
ax3 = plt.subplot(223)
baseline_losses = mloss_snr_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_snr_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_snr_cnn_dv_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_snr_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_snr_mlp_dv_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_snr_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_snr_unet_dv_all_select, axis=0)[::sparse_num]

ax3.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax3.plot(xlist, cnn_mean, linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax3.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax3.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)


# Improve axis style for second subplot
ax3.set_xlabel('Iterations', fontsize=15)
# ax3.set_ylabel('Signal-to-Noise Ratio', fontsize=12)
ax3.set_ylabel(r"SNR ($\uparrow$)", fontsize=14)
# ax3.set_title("Model Residual", fontsize=12)
ax3.grid(True, linestyle='--', alpha=0.6)

#######################################################
# Second subplot: Model Residual
ax4 = plt.subplot(224)
baseline_losses = mloss_ssim_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_ssim_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_ssim_cnn_dv_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_ssim_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_ssim_mlp_dv_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_ssim_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_ssim_unet_dv_all_select, axis=0)[::sparse_num]

ax4.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax4.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax4.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax4.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# Improve axis style for second subplot
ax4.set_xlabel('Iterations', fontsize=15)
# ax4.set_ylabel('Structural Similarity Index Meansure', fontsize=12)
ax4.set_ylabel(r'SSIM ($\uparrow$)', fontsize=14)
# ax4.set_title("Model Residual", fontsize=12)
ax4.grid(True, linestyle='--', alpha=0.6)


# -------------------------------------------------------------
ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)
ax3.tick_params(labelsize=12)
ax4.tick_params(labelsize=12)

ax1.text(-0.17, 0.95, "(a)", transform=ax1.transAxes, fontsize=14, va='bottom', ha='left')
ax2.text(-0.12, 0.95, "(b)", transform=ax2.transAxes, fontsize=14, va='bottom', ha='left')
ax3.text(-0.11, 0.95, "(c)", transform=ax3.transAxes, fontsize=14, va='bottom', ha='left')
ax4.text(-0.13, 0.95, "(d)", transform=ax4.transAxes, fontsize=14, va='bottom', ha='left')

# Adjust layout
plt.tight_layout()


# legend
ordered_labels = [
    "Traditional FWI",
    "CNN-$v_p$",
    "MLP-$v_p$",
    "Unet-$v_p$",
]
placeholder = Line2D([0], [0], linestyle='none', label='', color='white')  # 不显示的图例项
handles, labels = ax2.get_legend_handles_labels()
label_to_handle = dict(zip(labels, handles))
label_to_handle[""] = placeholder
ordered_handles = [label_to_handle[label] for label in ordered_labels]
legend = plt.figlegend(ordered_handles, ordered_labels, loc='lower center', ncol=4, fontsize=15, frameon=False, bbox_to_anchor=(0.52, -0.12))

fig.canvas.draw()  # 确保 legend 被渲染
legend_box = legend.get_window_extent(fig.canvas.get_renderer()).transformed(fig.transFigure.inverted())

# 添加背景色框
from matplotlib.patches import FancyBboxPatch
background = FancyBboxPatch(
    (legend_box.x0 - 0.01, legend_box.y0),  # 左下角坐标
    legend_box.width + 0.01,                      # 宽度
    legend_box.height + 0.01,                     # 高度
    boxstyle="round,pad=0.01",                    # 可选的圆角样式
    transform=fig.transFigure,
    facecolor='#f8f8f8',
    edgecolor='none',
    zorder=0
)
fig.patches.append(background)

plt.show()

# %% [markdown]
# ## Article Figure
#
# ### 1. loss curve

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.lines import Line2D
plt.rcParams['svg.fonttype'] = 'none'

palette = sns.color_palette("deep")
colors = {
    "Traditional FWI": "#4D4D4D",  # Dark gray
    "cnn_dv": palette[0],    # Blue for CNN-v
    "cnn_v": sns.dark_palette(palette[0], 2)[1],  # Darker blue for CNN-dv
    "mlp_dv": palette[1],    # Green for MLP-v
    "mlp_v": sns.dark_palette(palette[1], 2)[1],  # Darker green for MLP-dv
    "unet_dv": palette[2],   # Purple for Unet-v
    "unet_v": sns.dark_palette(palette[2], 2)[1]  # Darker purple for Unet-dv
}

# Set up the figure
fig = plt.figure(figsize=(12, 8))

#########################################################################################
# First subplot: Data Residual
ax1 = plt.subplot(221)
# Create inset zoom-in
sparse_num = 2
xlist = np.arange(MAX_ITER)[::sparse_num]

baseline_losses = dloss_baseline[::sparse_num]
cnn_mean  = np.mean(dloss_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(dloss_cnn_v_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(dloss_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(dloss_mlp_v_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(dloss_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(dloss_unet_v_all_select, axis=0)[::sparse_num]

ax1.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax1.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax1.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax1.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# ----------------------------------------------------------
cnn_mean  = np.mean(dloss_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(dloss_cnn_dv_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(dloss_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(dloss_mlp_dv_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(dloss_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(dloss_unet_dv_all_select, axis=0)[::sparse_num]

ax1.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax1.plot(xlist, cnn_mean,  linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax1.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax1.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax1.plot(xlist, unet_mean,  linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


ax1.set_ylabel('Global-Correlation Misfits', fontsize=14)
ax1.set_xticklabels([])
ax1.tick_params(axis="x", which="both", length=0)
ax1.grid(True, linestyle='--', alpha=0.6)

#######################################################
# Second subplot: Model Residual
ax2 = plt.subplot(222)

baseline_losses = mloss_mape_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_mape_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_mape_cnn_v_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_mape_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_mape_mlp_v_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_mape_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_mape_unet_v_all_select, axis=0)[::sparse_num]

ax2.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax2.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax2.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax2.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

#-----------------------------------------------------
cnn_mean  = np.mean(mloss_mape_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_mape_cnn_dv_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_mape_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_mape_mlp_dv_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_mape_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_mape_unet_dv_all_select, axis=0)[::sparse_num]

ax2.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax2.plot(xlist, cnn_mean,  linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax2.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax2.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax2.plot(xlist, unet_mean, linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


# Improve axis style
# ax2.set_ylabel('Mean Absolute Percentage Error', fontsize=12)
ax2.set_ylabel(r'MAPE ($\downarrow$)', fontsize=14)
# ax2.set_title("Model Residual", fontsize=12)
ax2.set_xticklabels([])  # Hide x-axis labels
ax2.tick_params(axis="x", which="both", length=0)
ax2.grid(True, linestyle='--', alpha=0.6)
# ax2.legend(loc='upper right', fontsize=10)


#######################################################
# Second subplot: Model Residual
ax3 = plt.subplot(223)
baseline_losses = mloss_snr_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_snr_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_snr_cnn_v_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_snr_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_snr_mlp_v_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_snr_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_snr_unet_v_all_select, axis=0)[::sparse_num]

ax3.plot(xlist, baseline_losses,  linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax3.plot(xlist, cnn_mean, linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax3.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax3.plot(xlist, unet_mean, linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# -----------------------------------------------------------

cnn_mean  = np.mean(mloss_snr_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_snr_cnn_dv_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_snr_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_snr_mlp_dv_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_snr_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_snr_unet_dv_all_select, axis=0)[::sparse_num]

ax3.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax3.plot(xlist, cnn_mean, linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax3.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax3.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax3.plot(xlist, unet_mean, linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


# Improve axis style for second subplot
ax3.set_xlabel('Iterations', fontsize=15)
# ax3.set_ylabel('Signal-to-Noise Ratio', fontsize=12)
ax3.set_ylabel(r"SNR ($\uparrow$)", fontsize=14)
# ax3.set_title("Model Residual", fontsize=12)
ax3.grid(True, linestyle='--', alpha=0.6)

#######################################################
# Second subplot: Model Residual
ax4 = plt.subplot(224)
baseline_losses = mloss_ssim_baseline[::sparse_num]
cnn_mean  = np.mean(mloss_ssim_cnn_v_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_ssim_cnn_v_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_ssim_mlp_v_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_ssim_mlp_v_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_ssim_unet_v_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_ssim_unet_v_all_select, axis=0)[::sparse_num]

ax4.plot(xlist, baseline_losses, linestyle='-', color=colors["Traditional FWI"],label="Traditional FWI", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_v"], alpha=0.2)
ax4.plot(xlist, cnn_mean,  linestyle='-', color=colors["cnn_v"], label=f"CNN-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_v"], alpha=0.2)
ax4.plot(xlist, mlp_mean,  linestyle='-', color=colors["mlp_v"], label="MLP-$v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_v"], alpha=0.2)
ax4.plot(xlist, unet_mean,  linestyle='-', color=colors["unet_v"], label="Unet-$v_p$", linewidth=2.5, markersize=5)

# -------------------------------------------------------------
cnn_mean  = np.mean(mloss_ssim_cnn_dv_all_select, axis=0)[::sparse_num]
cnn_std   = np.std(mloss_ssim_cnn_dv_all_select, axis=0)[::sparse_num]
mlp_mean  = np.mean(mloss_ssim_mlp_dv_all_select, axis=0)[::sparse_num]
mlp_std   = np.std(mloss_ssim_mlp_dv_all_select, axis=0)[::sparse_num]
unet_mean = np.mean(mloss_ssim_unet_dv_all_select, axis=0)[::sparse_num]
unet_std  = np.std(mloss_ssim_unet_dv_all_select, axis=0)[::sparse_num]

ax4.fill_between(xlist, (cnn_mean - cnn_std), (cnn_mean + cnn_std), color=colors["cnn_dv"], alpha=0.2)
ax4.plot(xlist, cnn_mean,  linestyle='--', color=colors["cnn_dv"], label=f"CNN-$\Delta v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (mlp_mean - mlp_std), (mlp_mean + mlp_std), color=colors["mlp_dv"], alpha=0.2)
ax4.plot(xlist, mlp_mean,  linestyle='--', color=colors["mlp_dv"], label=f"MLP-$\Delta v_p$", linewidth=2.5, markersize=5)
ax4.fill_between(xlist, (unet_mean - unet_std), (unet_mean + unet_std), color=colors["unet_dv"], alpha=0.2)
ax4.plot(xlist, unet_mean,  linestyle='--', color=colors["unet_dv"], label=f"Unet-$\Delta v_p$", linewidth=2.5, markersize=5)


# Improve axis style for second subplot
ax4.set_xlabel('Iterations', fontsize=15)
# ax4.set_ylabel('Structural Similarity Index Meansure', fontsize=12)
ax4.set_ylabel(r'SSIM ($\uparrow$)', fontsize=14)
# ax4.set_title("Model Residual", fontsize=12)
ax4.grid(True, linestyle='--', alpha=0.6)


# -------------------------------------------------------------
ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)
ax3.tick_params(labelsize=12)
ax4.tick_params(labelsize=12)

ax1.text(-0.17, 0.95, "(a)", transform=ax1.transAxes, fontsize=14, va='bottom', ha='left')
ax2.text(-0.12, 0.95, "(b)", transform=ax2.transAxes, fontsize=14, va='bottom', ha='left')
ax3.text(-0.11, 0.95, "(c)", transform=ax3.transAxes, fontsize=14, va='bottom', ha='left')
ax4.text(-0.13, 0.95, "(d)", transform=ax4.transAxes, fontsize=14, va='bottom', ha='left')

# Adjust layout
plt.tight_layout()


# legend
ordered_labels = [
    "Traditional FWI", "", 
    "CNN-$v_p$", "CNN-$\Delta v_p$", 
    "MLP-$v_p$", "MLP-$\Delta v_p$",
    "Unet-$v_p$", "Unet-$\Delta v_p$"
]
placeholder = Line2D([0], [0], linestyle='none', label='', color='white')  # 不显示的图例项
handles, labels = ax2.get_legend_handles_labels()
label_to_handle = dict(zip(labels, handles))
label_to_handle[""] = placeholder
ordered_handles = [label_to_handle[label] for label in ordered_labels]
legend = plt.figlegend(ordered_handles, ordered_labels, loc='lower center', ncol=4, fontsize=15, frameon=False, bbox_to_anchor=(0.52, -0.12))

fig.canvas.draw()  # 确保 legend 被渲染
legend_box = legend.get_window_extent(fig.canvas.get_renderer()).transformed(fig.transFigure.inverted())

# 添加背景色框
from matplotlib.patches import FancyBboxPatch
background = FancyBboxPatch(
    (legend_box.x0 - 0.01, legend_box.y0),  # 左下角坐标
    legend_box.width + 0.01,                      # 宽度
    legend_box.height + 0.01,                     # 高度
    boxstyle="round,pad=0.01",                    # 可选的圆角样式
    transform=fig.transFigure,
    facecolor='#f8f8f8',
    edgecolor='none',
    zorder=0
)
fig.patches.append(background)

# plt.savefig("./Figures/FigureS4_Architecture_and_Strategy_Marmousi2_Misfit.png",bbox_inches='tight',dpi=300)
plt.savefig("./Figures_SVG/FigureS4_Architecture_and_Strategy_Marmousi2_Misfit.svg",bbox_inches='tight',format="svg")
plt.show()

# %% [markdown]
# ### velocity model

# %%
def plot_vel_single_for_all(fig,ax,v,title="",MSE="",vmin=None,vmax=None,cmap = "rainbow"):
    plt.rc('font',family='Times New Roman')
    # plm = ax.pcolormesh(x_mesh, z_mesh, v,cmap=cmap,vmin=vmin,vmax=vmax)
    # x = np.arange(nx*3)*dx/3/1000
    # z = np.arange(nz*3)*dz/3/1000
    x = np.arange(nx)*dx/1000
    z = np.arange(nz)*dz/1000
    x_mesh_new,z_mesh_new = np.meshgrid(x,z)
    from scipy.interpolate import griddata
    v_new = griddata((x_mesh.flatten(), z_mesh.flatten()), v.flatten(), (x_mesh_new, z_mesh_new), method='cubic')
    
    plm = ax.pcolormesh(x_mesh_new, z_mesh_new, v_new,cmap=cmap,vmin=vmin,vmax=vmax,shading="nearest")
    ax.invert_yaxis()
    ax.tick_params(labelsize = 16)
    ax.set_title(title,fontsize=16)
    ax.text(0.2,0.4,MSE,fontsize=16,c="w")
    return plm

import matplotlib.transforms as mtransforms
def add_right_cax(ax, pad, width):
    axpos = ax.get_position()
    caxpos = mtransforms.Bbox.from_extents(
        axpos.x1 + pad,
        axpos.y0,
        axpos.x1 + pad + width,
        axpos.y1
    )
    cax = ax.figure.add_axes(caxpos)

    return cax

def add_bottom_cax(ax, pad, height):
    import matplotlib.transforms as mtransforms
    
    axpos = ax.get_position()
    caxpos = mtransforms.Bbox.from_extents(
        axpos.x0,
        axpos.y0 - pad - height,
        axpos.x1,
        axpos.y0 - pad
    )
    cax = ax.figure.add_axes(caxpos)
    
    return cax

def plot_vel_singleline_for_all(ax,v_true,v_init,v_inv,x_distance,title,show_xlabel=True,show_ylabel=False,show_legend=False):
    ax.plot(v_true[:,int(x_distance//dx)]/1000,  z, c='k',   linewidth=2, linestyle="-" ,label="True")
    ax.plot(v_init[:,int(x_distance//dx)]/1000,  z, c='gray',linewidth=2, linestyle="-" ,label="Init")
    ax.plot(v_inv [:,int(x_distance//dx)]/1000,  z, c='r',   linewidth=2, linestyle="--",label="Inverted")
    ax.tick_params(labelsize = 16)
    if not show_xlabel:
        ax.set_xticks([])
    # else:
    #     ax.tick_params(labelsize = 15)
        
    if not show_ylabel:
        ax.set_yticks([])
    else:
        ax.tick_params(labelsize = 12)
    ax.invert_yaxis()
    
    if show_legend:
        ax.legend(fontsize = 12)
    ax.set_title(title,fontsize=16)

# %%
best_cnn_v_idx = np.argmin(mloss_mape_cnn_v_all.min(axis=1))
best_cnn_dv_idx = np.argmin(mloss_mape_cnn_dv_all.min(axis=1))
best_mlp_v_idx = np.argmin(mloss_mape_mlp_v_all.min(axis=1))
best_mlp_dv_idx = np.argmin(mloss_mape_mlp_dv_all.min(axis=1))
best_unet_v_idx = np.argmin(mloss_mape_unet_v_all.min(axis=1))
best_unet_dv_idx = np.argmin(mloss_mape_unet_dv_all.min(axis=1))

print(best_cnn_v_idx,best_cnn_dv_idx,best_mlp_v_idx,best_mlp_dv_idx,best_unet_v_idx,best_unet_dv_idx)

# %%
mloss_mape_cnn_v_all.min(axis=1), mloss_mape_cnn_dv_all.min(axis=1)

# %%
itervp_CNN          = itervp_CNN_v_3x256[:MAX_ITER]
itervp_CNN_diff     = itervp_CNN_dv_2x64[:MAX_ITER]
itervp_MLP          = itervp_MLP_v_2x3000[:MAX_ITER]
itervp_MLP_diff     = itervp_MLP_dv_1x2000[:MAX_ITER]
itervp_Unet         = itervp_Unet_v_3x256[:MAX_ITER]
itervp_Unet_diff    = itervp_Unet_dv_3x64[:MAX_ITER]

# %%
plt.rcParams['svg.fonttype'] = 'none'

fig,axs = plt.subplots(4,2,figsize=(13,10))

im = plot_vel_single_for_all(fig,axs[0][0],true_v          ,title=r"True Model")
plot_vel_single_for_all(fig,axs[0][1],itervp_baseline[-1]  ,title=r"Traditional FWI"        ,MSE=f"(b) MAPE:{MAPE(true_v,itervp_baseline[-1]):.2f}")
plot_vel_single_for_all(fig,axs[1][0],itervp_Unet[-1]      ,title=r"Unet-$v_p$"             ,MSE=f"(c) MAPE:{MAPE(true_v,itervp_Unet[-1]):.2f}")
plot_vel_single_for_all(fig,axs[1][1],itervp_Unet_diff[-1] ,title=r"Unet-$\Delta v_p$"      ,MSE=f"(d) MAPE:{MAPE(true_v,itervp_Unet_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][0],itervp_MLP[-1]       ,title=r"MLP-$v_p$"              ,MSE=f"(e) MAPE:{MAPE(true_v,itervp_MLP[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][1],itervp_MLP_diff[-1]  ,title=r"MLP-$\Delta v_p$"       ,MSE=f"(f) MAPE:{MAPE(true_v,itervp_MLP_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][0],itervp_CNN[-1]       ,title=r"CNN-$v_p$"              ,MSE=f"(g) MAPE:{MAPE(true_v,itervp_CNN[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][1],itervp_CNN_diff[-1]  ,title=r"CNN-$\Delta v_p$"       ,MSE=f"(h) MAPE:{MAPE(true_v,itervp_CNN_diff[-1]):.2f}")

axs[0][0].scatter(rcv_x[1::2],rcv_z[1::2]+0.05,c="w",marker="v",s=10)
axs[0][0].scatter(src_x[1::2],src_z[1::2]+0.05,c="r",marker="*",s=60)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)

axs[1][0].set_ylabel("Depth (km)",fontsize=15)
axs[2][0].set_ylabel("Depth (km)",fontsize=15)
axs[3][0].set_ylabel("Depth (km)",fontsize=15)

axs[0][0].set_xticks([])
axs[0][1].set_xticks([])
axs[0][1].set_yticks([])

axs[1][0].set_xticks([])
axs[1][1].set_xticks([])
axs[1][1].set_yticks([])

axs[2][0].set_xticks([])
axs[2][1].set_xticks([])
axs[2][1].set_yticks([])

axs[3][1].set_yticks([])

from matplotlib.ticker import MaxNLocator
axs[0][0].yaxis.set_major_locator(MaxNLocator(5))
axs[1][0].yaxis.set_major_locator(MaxNLocator(5))
axs[2][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].xaxis.set_major_locator(MaxNLocator(8))
axs[3][1].xaxis.set_major_locator(MaxNLocator(8))

axs[3][0].set_xlabel("Distance (km)", fontsize=15)
axs[3][1].set_xlabel("Distance (km)", fontsize=15)

plt.subplots_adjust(hspace=0.2,wspace=0.03)

cbar = fig.colorbar(im, ax=axs,orientation='vertical',pad = 0.02,shrink=0.6)
cbar.ax.set_title("(m/s)",fontsize=15,loc='center')
cbar.ax.tick_params(labelsize=15)

axs[0][0].text(0.03, 0.82, "(a)", transform=axs[0][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='w')

# plt.savefig("./Figures/FigureS5_Architecture_and_Strategy_Marmousi2_model.png",bbox_inches='tight',dpi=300)
# plt.savefig("./Figures_SVG/FigureS5_Architecture_and_Strategy_Marmousi2_model.svg",bbox_inches='tight',format="svg")
plt.savefig("./Figures_PDF/FigureS5_Architecture_and_Strategy_Marmousi2_model.pdf",bbox_inches='tight',format="pdf")
plt.show()

# %%
fig,axs = plt.subplots(4,2,figsize=(13,10))
iter = 0
im = plot_vel_single_for_all(fig,axs[0][0],init_v            ,title=r"Initial Model")
plot_vel_single_for_all(fig,axs[0][1],itervp_baseline[iter]  ,title=r"Traditional FWI"        ,MSE=f"(b) MAPE:{MAPE(true_v,itervp_baseline[iter]):.2f}")
plot_vel_single_for_all(fig,axs[1][0],itervp_Unet[iter]      ,title=r"Unet-$v_p$"             ,MSE=f"(c) MAPE:{MAPE(true_v,itervp_Unet[iter]):.2f}")
plot_vel_single_for_all(fig,axs[1][1],itervp_Unet_diff[iter] ,title=r"Unet-$\Delta v_p$"      ,MSE=f"(d) MAPE:{MAPE(true_v,itervp_Unet_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][0],itervp_MLP[iter]       ,title=r"MLP-$v_p$"              ,MSE=f"(e) MAPE:{MAPE(true_v,itervp_MLP[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][1],itervp_MLP_diff[iter]  ,title=r"MLP-$\Delta v_p$"       ,MSE=f"(f) MAPE:{MAPE(true_v,itervp_MLP_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][0],itervp_CNN[iter]       ,title=r"CNN-$v_p$"              ,MSE=f"(g) MAPE:{MAPE(true_v,itervp_CNN[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][1],itervp_CNN_diff[iter]  ,title=r"CNN-$\Delta v_p$"       ,MSE=f"(h) MAPE:{MAPE(true_v,itervp_CNN_diff[-1]):.2f}")

axs[0][0].scatter(rcv_x[1::2],rcv_z[1::2]+0.05,c="w",marker="v",s=10)
axs[0][0].scatter(src_x[1::2],src_z[1::2]+0.05,c="r",marker="*",s=60)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)

axs[1][0].set_ylabel("Depth (km)",fontsize=15)
axs[2][0].set_ylabel("Depth (km)",fontsize=15)
axs[3][0].set_ylabel("Depth (km)",fontsize=15)

axs[0][0].set_xticks([])
axs[0][1].set_xticks([])
axs[0][1].set_yticks([])

axs[1][0].set_xticks([])
axs[1][1].set_xticks([])
axs[1][1].set_yticks([])

axs[2][0].set_xticks([])
axs[2][1].set_xticks([])
axs[2][1].set_yticks([])

axs[3][1].set_yticks([])

from matplotlib.ticker import MaxNLocator
axs[0][0].yaxis.set_major_locator(MaxNLocator(5))
axs[1][0].yaxis.set_major_locator(MaxNLocator(5))
axs[2][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].xaxis.set_major_locator(MaxNLocator(8))
axs[3][1].xaxis.set_major_locator(MaxNLocator(8))

axs[3][0].set_xlabel("Distance (km)", fontsize=15)
axs[3][1].set_xlabel("Distance (km)", fontsize=15)

plt.subplots_adjust(hspace=0.2,wspace=0.03)

cbar = fig.colorbar(im, ax=axs,orientation='vertical',pad = 0.02,shrink=0.6)
cbar.ax.set_title("(m/s)",fontsize=15,loc='center')
cbar.ax.tick_params(labelsize=15)

axs[0][0].text(0.03, 0.82, "(a)", transform=axs[0][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='w')

plt.savefig(f"./Figures/FigureR1_Architecture_and_Strategy_Marmousi2_model_iter{iter}.png",bbox_inches='tight',dpi=300)
plt.show()

# %%
fig,axs = plt.subplots(4,2,figsize=(13,10))
iter = 50
im = plot_vel_single_for_all(fig,axs[0][0],init_v            ,title=r"Initial Model")
plot_vel_single_for_all(fig,axs[0][1],itervp_baseline[iter]  ,title=r"Traditional FWI"        ,MSE=f"(b) MAPE:{MAPE(true_v,itervp_baseline[iter]):.2f}")
plot_vel_single_for_all(fig,axs[1][0],itervp_Unet[iter]      ,title=r"Unet-$v_p$"             ,MSE=f"(c) MAPE:{MAPE(true_v,itervp_Unet[iter]):.2f}")
plot_vel_single_for_all(fig,axs[1][1],itervp_Unet_diff[iter] ,title=r"Unet-$\Delta v_p$"      ,MSE=f"(d) MAPE:{MAPE(true_v,itervp_Unet_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][0],itervp_MLP[iter]       ,title=r"MLP-$v_p$"              ,MSE=f"(e) MAPE:{MAPE(true_v,itervp_MLP[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][1],itervp_MLP_diff[iter]  ,title=r"MLP-$\Delta v_p$"       ,MSE=f"(f) MAPE:{MAPE(true_v,itervp_MLP_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][0],itervp_CNN[iter]       ,title=r"CNN-$v_p$"              ,MSE=f"(g) MAPE:{MAPE(true_v,itervp_CNN[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][1],itervp_CNN_diff[iter]  ,title=r"CNN-$\Delta v_p$"       ,MSE=f"(h) MAPE:{MAPE(true_v,itervp_CNN_diff[-1]):.2f}")

axs[0][0].scatter(rcv_x[1::2],rcv_z[1::2]+0.05,c="w",marker="v",s=10)
axs[0][0].scatter(src_x[1::2],src_z[1::2]+0.05,c="r",marker="*",s=60)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)

axs[1][0].set_ylabel("Depth (km)",fontsize=15)
axs[2][0].set_ylabel("Depth (km)",fontsize=15)
axs[3][0].set_ylabel("Depth (km)",fontsize=15)

axs[0][0].set_xticks([])
axs[0][1].set_xticks([])
axs[0][1].set_yticks([])

axs[1][0].set_xticks([])
axs[1][1].set_xticks([])
axs[1][1].set_yticks([])

axs[2][0].set_xticks([])
axs[2][1].set_xticks([])
axs[2][1].set_yticks([])

axs[3][1].set_yticks([])

from matplotlib.ticker import MaxNLocator
axs[0][0].yaxis.set_major_locator(MaxNLocator(5))
axs[1][0].yaxis.set_major_locator(MaxNLocator(5))
axs[2][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].xaxis.set_major_locator(MaxNLocator(8))
axs[3][1].xaxis.set_major_locator(MaxNLocator(8))

axs[3][0].set_xlabel("Distance (km)", fontsize=15)
axs[3][1].set_xlabel("Distance (km)", fontsize=15)

plt.subplots_adjust(hspace=0.2,wspace=0.03)

cbar = fig.colorbar(im, ax=axs,orientation='vertical',pad = 0.02,shrink=0.6)
cbar.ax.set_title("(m/s)",fontsize=15,loc='center')
cbar.ax.tick_params(labelsize=15)

axs[0][0].text(0.03, 0.82, "(a)", transform=axs[0][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='w')

plt.savefig(f"./Figures/FigureR1_Architecture_and_Strategy_Marmousi2_model_iter{iter}.png",bbox_inches='tight',dpi=300)
plt.show()

# %%
fig,axs = plt.subplots(4,2,figsize=(13,10))
iter = 200
im = plot_vel_single_for_all(fig,axs[0][0],init_v            ,title=r"Initial Model")
plot_vel_single_for_all(fig,axs[0][1],itervp_baseline[iter]  ,title=r"Traditional FWI"        ,MSE=f"(b) MAPE:{MAPE(true_v,itervp_baseline[iter]):.2f}")
plot_vel_single_for_all(fig,axs[1][0],itervp_Unet[iter]      ,title=r"Unet-$v_p$"             ,MSE=f"(c) MAPE:{MAPE(true_v,itervp_Unet[iter]):.2f}")
plot_vel_single_for_all(fig,axs[1][1],itervp_Unet_diff[iter] ,title=r"Unet-$\Delta v_p$"      ,MSE=f"(d) MAPE:{MAPE(true_v,itervp_Unet_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][0],itervp_MLP[iter]       ,title=r"MLP-$v_p$"              ,MSE=f"(e) MAPE:{MAPE(true_v,itervp_MLP[-1]):.2f}")
plot_vel_single_for_all(fig,axs[2][1],itervp_MLP_diff[iter]  ,title=r"MLP-$\Delta v_p$"       ,MSE=f"(f) MAPE:{MAPE(true_v,itervp_MLP_diff[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][0],itervp_CNN[iter]       ,title=r"CNN-$v_p$"              ,MSE=f"(g) MAPE:{MAPE(true_v,itervp_CNN[-1]):.2f}")
plot_vel_single_for_all(fig,axs[3][1],itervp_CNN_diff[iter]  ,title=r"CNN-$\Delta v_p$"       ,MSE=f"(h) MAPE:{MAPE(true_v,itervp_CNN_diff[-1]):.2f}")

axs[0][0].scatter(rcv_x[1::2],rcv_z[1::2]+0.05,c="w",marker="v",s=10)
axs[0][0].scatter(src_x[1::2],src_z[1::2]+0.05,c="r",marker="*",s=60)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)
axs[0][0].set_ylabel("Depth (km)",fontsize=15)

axs[1][0].set_ylabel("Depth (km)",fontsize=15)
axs[2][0].set_ylabel("Depth (km)",fontsize=15)
axs[3][0].set_ylabel("Depth (km)",fontsize=15)

axs[0][0].set_xticks([])
axs[0][1].set_xticks([])
axs[0][1].set_yticks([])

axs[1][0].set_xticks([])
axs[1][1].set_xticks([])
axs[1][1].set_yticks([])

axs[2][0].set_xticks([])
axs[2][1].set_xticks([])
axs[2][1].set_yticks([])

axs[3][1].set_yticks([])

from matplotlib.ticker import MaxNLocator
axs[0][0].yaxis.set_major_locator(MaxNLocator(5))
axs[1][0].yaxis.set_major_locator(MaxNLocator(5))
axs[2][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].yaxis.set_major_locator(MaxNLocator(5))
axs[3][0].xaxis.set_major_locator(MaxNLocator(8))
axs[3][1].xaxis.set_major_locator(MaxNLocator(8))

axs[3][0].set_xlabel("Distance (km)", fontsize=15)
axs[3][1].set_xlabel("Distance (km)", fontsize=15)

plt.subplots_adjust(hspace=0.2,wspace=0.03)

cbar = fig.colorbar(im, ax=axs,orientation='vertical',pad = 0.02,shrink=0.6)
cbar.ax.set_title("(m/s)",fontsize=15,loc='center')
cbar.ax.tick_params(labelsize=15)

axs[0][0].text(0.03, 0.82, "(a)", transform=axs[0][0].transAxes, fontsize=15, verticalalignment='bottom', horizontalalignment='left',c='w')

plt.savefig(f"./Figures/FigureR1_Architecture_and_Strategy_Marmousi2_model_iter{iter}.png",bbox_inches='tight',dpi=300)
plt.show()
